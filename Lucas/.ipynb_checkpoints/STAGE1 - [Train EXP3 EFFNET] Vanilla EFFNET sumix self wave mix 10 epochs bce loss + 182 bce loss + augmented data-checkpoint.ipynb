# %%
# %%capture
# !pip install torch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2 --index-url https://download.pytorch.org/whl/cu121
# !pip install pytorch_lightning==2.1
# !pip install pandas librosa opencv-python matplotlib  #cupy-cuda110 
# !pip install -U albumentations
# import timm

# %%
import pandas as pd
import os
import torch
from IPython.display import display, Audio
import librosa
import math
import numpy as np
import scipy
from scipy import signal as sci_signal
import cv2
import matplotlib.pyplot as plt
import gc
import sys
import numpy as np
from glob import glob
from tqdm import tqdm
import pytorch_lightning as pl
import albumentations as albu
from torchvision.models import efficientnet
import torch.nn as nn
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
from pytorch_lightning.callbacks import ModelCheckpoint, TQDMProgressBar
import pandas as pd
import pandas.api.types
import sklearn.metrics
from sklearn.model_selection import KFold, train_test_split, StratifiedKFold
from torch.utils.data import WeightedRandomSampler

mel_spec_params = {
    "sample_rate": 32000,
    "n_mels": 128,
    "f_min": 20,
    "f_max": 16000,
    "n_fft": 2048,
    "hop_length": 512,
    "normalized": True,
    "center" : True,
    "pad_mode" : "constant",
    "norm" : "slaney",
    "onesided" : True,
    "mel_scale" : "slaney"
}
def normalize_melspec(X, eps=1e-6):
    mean = X.mean((1, 2), keepdim=True)
    std = X.std((1, 2), keepdim=True)
    Xstd = (X - mean) / (std + eps)

    norm_min, norm_max = (
        Xstd.min(-1)[0].min(-1)[0],
        Xstd.max(-1)[0].max(-1)[0],
    )
    fix_ind = (norm_max - norm_min) > eps * torch.ones_like(
        (norm_max - norm_min)
    )
    V = torch.zeros_like(Xstd)
    if fix_ind.sum():
        V_fix = Xstd[fix_ind]
        norm_max_fix = norm_max[fix_ind, None, None]
        norm_min_fix = norm_min[fix_ind, None, None]
        V_fix = torch.max(
            torch.min(V_fix, norm_max_fix),
            norm_min_fix,
        )
        V_fix = (V_fix - norm_min_fix) / (norm_max_fix - norm_min_fix)
        V[fix_ind] = V_fix
    return V

# %%
class ParticipantVisibleError(Exception):
    pass


def score(solution: pd.DataFrame, submission: pd.DataFrame, row_id_column_name: str) -> float:
    '''
    Version of macro-averaged ROC-AUC score that ignores all classes that have no true positive labels.
    '''
    del solution[row_id_column_name]
    del submission[row_id_column_name]

    if not pandas.api.types.is_numeric_dtype(submission.values):
        bad_dtypes = {x: submission[x].dtype  for x in submission.columns if not pandas.api.types.is_numeric_dtype(submission[x])}
        raise ParticipantVisibleError(f'Invalid submission data types found: {bad_dtypes}')

    solution_sums = solution.sum(axis=0)
    scored_columns = list(solution_sums[solution_sums > 0].index.values)
    assert len(scored_columns) > 0

    return sklearn.metrics.roc_auc_score(solution[scored_columns].values, submission[scored_columns].values, average='macro')

# %%
class CONFIG:
    
    # == GENERAL ==
    seed = 42                             # random seed
    device = 'cuda'                         # device to be used
    mix_precision = False                   # whether to use mixed-16 precision
    
    # == DATA ==
    preprocess = True
    preprocessed_data = '../../preprocessed_data/imgs_v0/'                  # Path for processed data to be stores (Must put on .gitignore to not send to repo)
    checkpoint_dir = '../chpks/exp1_xcamodel_5sec_selfmixup_sumixup_mixup_cutmix_30epochs_182bce_bce_augmenteddata'  # Checkpoints path (Must put on .gitignore to not send to repo)
    data_dir_2024 = '../../data/2024'# root folder
    sr = 32000                              # sampling rate
    n_fft = 1095                            # NFFT of Spec.
    win_len = 412                          # WIN_SIZE of Spec.
    hop_len = 100                         # overlap of Spec.
    min_freq = 40                           # min frequency
    max_freq = 15000                        # max frequency
    
    # == MODEL ==
    model = 'efficientnet_b0'               # model architecture
    
    # == DATASET ==
    batch_size = 32                         # batch size of each step
    n_workers = 4                           # number of workers
    
    # == AUG ==
    USE_HORIZFLIP = True
    USE_XYMASKING = True                    # whether use XYMasking

    # == TRAINING ==
    folds = 5                              # n fold
    epochs = 30                             # max epochs
    epochs_stage_1 = 5
    epochs_stage_2 = 10
    lr = 1e-3                               # learning rate
    weight_decay = 1e-3                     # weight decay of optimizer
    visualize = True                        # whether to visualize data and batch

# %%
df = pd.read_csv("2024_with_30sec_slices.csv")
df.head()

# Labels
label_list = sorted(df['primary_label'].unique())
label_id_list = list(range(len(label_list)))
label2id = dict(zip(label_list, label_id_list))
id2label = dict(zip(label_id_list, label_list))

train_df = df[['primary_label', 'sliced_path','wav_path','secondary_labels','rating']].copy()  # Uses only audio, label and rating.

# Create Target
train_df['target'] = train_df.primary_label.map(label2id)

# Create Filepath
# train_df['filepath'] = CONFIG.data_dir_2024 + '/train_audio/' + train_df.filename

# Create Name
train_df['name'] = train_df.wav_path.map(lambda x: x.split('/')[0] + '-' + x.split('/')[-1].split('.')[0])

# %%
import torchaudio
def preprocess_fn(filepath, input_audio = None):

    if(input_audio is not None):
        waveform = input_audio
    else:
    # LOAD .OGG
        waveform, sample_rate = torchaudio.load(filepath, normalize=True)
        # waveform = waveform[:5*sample_rate]

    # print(len(waveform.shape))
    # if(len(waveform.shape) < 2):
        # waveform
    
    transform = torchaudio.transforms.MelSpectrogram(**mel_spec_params)
    spectrogram = transform(waveform)
    db_transform = torchaudio.transforms.AmplitudeToDB(stype='power', top_db=80)
    spectrogram = db_transform(spectrogram)

    # print(spectrogram.shape)
    spec_data = normalize_melspec(spectrogram).squeeze(0) 
    # spec_data = spec_data.expand(3, -1, -1).permute(1, 2, 0).numpy()
    
    # print(spec_data.shape)
    # spec_data = albu.Resize(256, 256)(image=spec_data)
    # spec_data = albu.Normalize()(image=spec_data['image'])['image'].astype(np.float32)
    # spec = res['image'].astype(np.float32)
    # spec_data = spec_data.transpose(2, 0, 1)
    # print(spec_data['image'].shape)
    return spec_data

# %%
# Just testing

processed_spec_left = preprocess_fn(train_df['sliced_path'].values[0])
processed_spec_center = preprocess_fn(train_df['sliced_path'].values[1])
processed_spec_right = preprocess_fn(train_df['sliced_path'].values[2])

plt.figure()
plt.title('LEFT')
plt.imshow(processed_spec_left, origin='lower')
plt.show()

plt.figure()
plt.title('CENTER')
plt.imshow(processed_spec_center, origin='lower')
plt.show()

plt.figure()
plt.title("RIGHT")
plt.imshow(processed_spec_right, origin='lower')
plt.show()

# %%
processed_spec_center.shape, processed_spec_center.mean(), processed_spec_center.min()
# Out:
# (torch.Size([128, 1876]), tensor(0.5328), tensor(0.))

# %%
import torchaudio.transforms as T
import torchaudio
import numpy

# %%
import random
class BackgroundAugmentation(object):
    def __init__(self, min_scale, max_scale, back_df, mode = 'train'):
        self.min_scale = min_scale
        self.max_scale = max_scale
        self.backgrounds = back_df
        self.mode = mode

    def __call__(self, waveform):
        numero_aleatorio = random.randint(0, len(self.backgrounds)-1)
        noise_path = self.backgrounds.sliced_path.values[numero_aleatorio]
        noise, sample_rate = librosa.load(noise_path, sr = None)

        # Getting 5 seconds through a p.05 selfmixup
        rand_scale = random.uniform(0, 1)
        ridx = random.randint(0, 5)
        if(rand_scale > 0.5):
            wave = selfmixup(data=noise.reshape(-1, 5*32000), alpha=0.95)
            noise = wave[ridx:ridx+1, :][0]

        else:
            noise = noise[ridx*32000:(ridx+5)*32000]
            
        
        # noise = np.concatenate([noise]*3) #if training with 15sec
            
        rand_scale = random.uniform(self.min_scale, self.max_scale)
#         print(rand_scale)
        noisy_speech = (rand_scale * waveform + noise) / (1+rand_scale)
#         print(waveform.mean(), noisy_speech.mean())
        return noisy_speech

# %%
def selfmixup(data, alpha):
    
    data = torch.tensor(data)
    indices = torch.randperm(data.size(0))
    shuffled_data = data[indices]
    # shuffled_targets = targets[indices]
    #print(indices)
    lam = np.random.beta(alpha, alpha)
    # print(lam)
    #print(lam)
    new_data = data * lam + shuffled_data * (1 - lam)
    # new_targets = targets * lam + shuffled_targets * (1 - lam)
    return new_data.numpy()

# %%
# list_augs = os.listdir('../../preprocessed_data/5sec_unlabeleds_center/')
# list_augs = ['../../preprocessed_data/5sec_unlabeleds_center/' + w for w in list_augs]

# ex_df = pd.DataFrame({'wav_path': list_augs})
ex_df = pd.read_csv('2024_unlabelled_with_30sec_slices.csv')

# %%
backaud = BackgroundAugmentation(0.1,0.1, ex_df, mode = 'train')

# %%
train_df.head(2)
# Out:
#   primary_label                                        sliced_path  \
# 0        asbfly  ../../preprocessed_data/2024_30sec/data_2024_t...
# 1        asbfly  ../../preprocessed_data/2024_30sec/data_2024_t...
#
#                                           wav_path secondary_labels  rating  \
# 0  ../../data/2024/train_audio/asbfly/XC134896.ogg               []     5.0
# 1  ../../data/2024/train_audio/asbfly/XC164848.ogg               []     2.5
#
#    target         name
# 0       0  ..-XC134896
# 1       0  ..-XC164848

# %%
ex = train_df['sliced_path'].values[3]
waveform, sample_rate = librosa.load(ex, sr = None)
print(len(waveform)/sample_rate, sample_rate)
waveform = backaud(waveform[:5*32000])
Audio(waveform, rate = sample_rate)
# Out:
# 30.0 32000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ex_df_train, ex_df_val = train_test_split(ex_df, test_size = 0.2, random_state = 42)

# %%
y , sr = librosa.load(train_df.sliced_path[0], sr = None)
print(sr, y.shape)
wave = selfmixup(data=y.reshape(-1, 5*32000), alpha=0.95)
# Out:
# 32000 (960000,)

# %%
import random
class SumMixUp(object):
    def __init__(self, df, labels, min_pct= 0.3, max_pct=1):
        self.df = df
        self.labels = labels
        self.min_pct = min_pct
        self.max_pct = max_pct

    def __call__(self, waveform, label):
        idx = random.randint(0, len(self.df)-1)
        noise_path = self.df.sliced_path.values[idx]
        random_wav, sample_rate = librosa.load(noise_path, sr = None)

        #dont need it here
        # # Getting 5 seconds through a p.05 selfmixup
        # rand_scale = random.uniform(0, 1)
        # ridx = random.randint(0, 5)
        # if(rand_scale > 0.5):
        #     wave = selfmixup(data=random_wav.reshape(-1, 5*32000), alpha=0.95)
        #     random_wav = wave[ridx:ridx+1, :][0]

        # else:
        #     random_wav = random_wav[ridx*32000:(ridx+5)*32000]

        
        random_label = self.labels[idx]

        rand1 = random.uniform(0, self.max_pct - self.min_pct) + self.min_pct
        rand2 = random.uniform(0, self.max_pct - self.min_pct) + self.min_pct


        ridx = random.randint(0, 5) # Works because of 6 * 5sec chunks
        waveform = rand1*waveform + rand2*random_wav[ridx*32000:(ridx+5)*32000]
        
        if rand1 >= 0.5:
            rand1 = 1
        else:
            rand1 = 1 - 2*(0.5 - rand1)

        if rand2 >= 0.5:
            rand2 = 1
        else:
            rand2 = 1*(1 - 2*(0.5 - rand2))

        # print(rand1, rand2)
        
        label = rand1*label + rand2*random_label

        # print(label)
        return waveform , np.clip(label, 0 ,1)

# %%
labels = np.eye(182)[train_df["target"].astype(int).values]

# %%
smu = SumMixUp(train_df, labels)

# %%
i = 2
y , sr = librosa.load(train_df.sliced_path[i], sr = None)
print(sr, y.shape)
wave, l = smu(y[:5*32000], labels[i])
Audio(wave, rate = sr)
# Out:
# 32000 (960000,)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
class BirdDataset(torch.utils.data.Dataset):
    
    def __init__(
        self,
        df,
        back_augmentation = None,
        use_sumixup = False,
        spec_augmentation=None,
        mode='train',
        n_sumixup =1
    ):
        super().__init__()
        self.df = df
        self.back_augmentation = back_augmentation
        self.summixup = None
        self.spec_augmentation = spec_augmentation
        self.mode = mode
        self.labels = np.eye(self.df.target.nunique())[self.df["target"].astype(int).values]
        self.n_sumixup = n_sumixup
        if use_sumixup:
            print("Using SumMixUp")
            self.summixup = SumMixUp(self.df, self.labels)

        if self.back_augmentation is not None:
            print("Using random background noise of unlabelled soundscapes")
    
    def __len__(self):
        return len(self.df)
    
    # def __getitem__(self, index):
    def __getitem__(self, index):
        wav_path = self.df.sliced_path.values[index]
        # target
        target = self.labels[index]
        
        input_audio, sr = torchaudio.load(wav_path, normalize=True)
        input_audio = input_audio[0].numpy()

        rand_scale = random.uniform(0, 1)
        ridx = random.randint(0, 5)
        if(rand_scale > 0.2):
            wave = selfmixup(data=input_audio.reshape(-1, 5*32000), alpha=0.95)
            input_audio = wave[ridx:ridx+1, :][0]

        else:
            input_audio = input_audio[ridx*32000:(ridx+5)*32000]

        if self.summixup is not None:
            # print('using sumixup')
            for _ in range(self.n_sumixup):
                rand_scale = random.uniform(0, 1)
                if(rand_scale > 0.3):
                    input_audio, target = self.summixup(input_audio, target)
            
        # aug
        if self.back_augmentation is not None:
            # print('using backaug')
            rand_scale = random.uniform(0, 1)
            if(rand_scale > 0.3 and self.mode == 'train'):
                input_audio = self.back_augmentation(input_audio)
            if(self.mode == 'valid'):
                input_audio = self.back_augmentation(input_audio)
                
        input_spec = preprocess_fn('', input_audio = torch.tensor(input_audio).unsqueeze(0))
        
        if self.spec_augmentation is not None:
            input_spec = self.spec_augmentation(image=input_spec.numpy())['image']
        
        return torch.tensor(input_spec, dtype=torch.float32) ,torch.tensor(target.astype(np.float32))

# %%
def get_transforms(_type):
    
    if _type == 'train':
        return albu.Compose([
            albu.GaussNoise(var_limit=(0.01, 0.05), mean=0),
            albu.HorizontalFlip(0.5) if CONFIG.USE_XYMASKING else albu.NoOp(),
            albu.XYMasking(
                p=0.3,
                num_masks_x=(1, 5),
                num_masks_y=(1, 3),
                mask_x_length=(1, 20),
                mask_y_length=(1, 5),
            ) if CONFIG.USE_XYMASKING else albu.NoOp()
        ])
    elif _type == 'valid':
        return albu.Compose([])

# %%
def show_batch(ds, row=3, col=3):
    fig = plt.figure(figsize=(10, 10))
    img_index = np.random.randint(0, len(ds)-1, row*col)
    
    for i in range(len(img_index)):
        img, label = dummy_dataset[img_index[i]]
        
        if isinstance(img, torch.Tensor):
            # print(img.min().item())
            min_ = img.min().item()
            max_ = img.max().item()
            # print(min_, max_)
            # print(img_index[i], img)
            img = img.detach().numpy()
            # print(img.min(), img.max())
        
        ax = fig.add_subplot(row, col, i + 1, xticks=[], yticks=[])
        # ax.imshow(img, cmap='jet')
        ax.imshow(img)
        ax.set_title(f'ID: {img_index[i]}; Target: {label.argmax()}')
    
    plt.tight_layout()
    plt.show()

# %%
backaud = BackgroundAugmentation(0.1,0.1, ex_df, 'train')

dummy_dataset = BirdDataset( 
        train_df,
        back_augmentation = backaud,
        use_sumixup = True,
        spec_augmentation=get_transforms('train'),
        mode='train')

test_input, test_target = dummy_dataset[0]
print(test_input.detach().numpy().shape)

show_batch(dummy_dataset)
# Out:
# Using SumMixUp
# Using random background noise of unlabelled soundscapes
# (128, 313)

# %%
del dummy_dataset
gc.collect()
# Out:
# 20943

# %%
# Getting original splits
kf = StratifiedKFold(n_splits=CONFIG.folds, shuffle=True, random_state=CONFIG.seed)
train_df['fold'] = 0
for fold, (train_idx, val_idx) in enumerate(kf.split(train_df, y=train_df['target'])):
    for idx in val_idx:
        train_df.iloc[idx, train_df.columns.get_loc('fold') ] = fold

# %%
# # Reading additional data
aug_df = pd.read_csv("past_competition_30sec_slices.csv")
aug_df.head(2)
# Out:
#                                             wav_path primary_label  \
# 0  ../../data/2021/train_short_audio/acafly/XC109...        acafly
# 1  ../../data/2021/train_short_audio/acafly/XC112...        acafly
#
#   secondary_labels  rating             filename  mapped  \
# 0       ['amegfi']     2.5  acafly_XC109605.ogg     132
# 1               []     3.0   acafly_XC11209.ogg     132
#
#                                          sliced_path
# 0  ../../preprocessed_data/2021_2022_2023_30sec/d...
# 1  ../../preprocessed_data/2021_2022_2023_30sec/d...

# %%
aug_df['maped'] = aug_df.primary_label.map(aug_df.primary_label.value_counts())
aug_df = aug_df[(aug_df.maped > 10) & (aug_df.maped < 500)]
aug_df.primary_label.nunique()
# Out:
# 668

# %%
# # Labels
init_new_label = 182
for p in aug_df.primary_label.unique():
    if p not in label2id.keys():
        label2id[p] = init_new_label
        init_new_label+= 1
        
id2label = dict(zip(label_id_list, label_list))

aug_df = aug_df[['primary_label', 'sliced_path','secondary_labels','rating']].copy()  # Uses only audio, label and rating.

# # Create Target
aug_df['target'] = aug_df.primary_label.map(label2id)

# %%
aug_df.target.value_counts()
# Out:
# target
# 177    486
# 319    485
# 191    481
# 10     481
# 693    477
#       ...
# 592     12
# 651     12
# 669     11
# 581     11
# 622     11
# Name: count, Length: 668, dtype: int64

# %%
# Getting augmented splits
kf = StratifiedKFold(n_splits=CONFIG.folds, shuffle=True, random_state=CONFIG.seed)
aug_df['fold'] = 0
for fold, (train_idx, val_idx) in enumerate(kf.split(aug_df, y=aug_df['target'])):
    for idx in val_idx:
        aug_df.iloc[idx, aug_df.columns.get_loc('fold') ] = fold

# %%
train_df = pd.concat([train_df, aug_df]).reset_index(drop=True)
train_df.fold.value_counts()
# Out:
# fold
# 1    20391
# 3    20391
# 2    20391
# 0    20391
# 4    20390
# Name: count, dtype: int64

# %%
train_df.target.value_counts()
# Out:
# target
# 177    981
# 10     979
# 80     934
# 55     861
# 106    780
#       ...
# 178      6
# 16       6
# 5        5
# 92       5
# 119      5
# Name: count, Length: 830, dtype: int64

# %%
for fold in train_df.fold.unique():
    print(train_df[train_df['fold']== fold].primary_label.nunique())
# Out:
# 830
# 830
# 830
# 830
# 830

# %%
full_label_list = sorted(train_df['primary_label'].unique())
len(full_label_list)
# Out:
# 830

# %%
from model_soup import XCAMetaBird
# class EffNet(nn.Module):
    
#     def __init__(self, n_classes):
#         super().__init__()
        
#         self.base_model = efficientnet.efficientnet_b0(weights=efficientnet.EfficientNet_B0_Weights.DEFAULT)

        
#         self.base_model.classifier[1] = nn.Linear(self.base_model.classifier[1].in_features, n_classes, dtype=torch.float32)
    
#     def forward(self, x):
#         # x = x.unsqueeze(-1)
#         # x = torch.cat([x, x, x], dim=3).permute(0, 3, 1, 2)
#         x = x.unsqueeze(1)
#         x = x.expand(-1, 3, -1, -1)
#         return self.base_model(x)

# %%
class MyModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.backbone = XCAMetaBird(128,128,734)
        cpt = torch.load('./pre_trained_weights/xca_128emb_pastcompetition_mixup_cutmix/best_model_220968_61.pth', map_location='cpu')
        self.backbone.load_state_dict(cpt)

        self.backbone.classifier_layer = nn.Linear(128, 830)
        # self.classifier_layer = nn.Linear(734,182)
        # print(self.backbone)
    def forward(self, mel):
        return self.backbone(mel)

# %%
# cpt = torch.load('./pre_trained_weights/xca_128emb_pastcompetition_mixup_cutmix/best_model_220968_61.pth')
# cpt

# %%
n = MyModel()

x = torch.rand((2,128,313))
y = torch.randint(low=0, high=335, size=(1,1))[0]

pred = n(x)
pred.shape
# Out:
# torch.Size([2, 830])

# %%
del n 
gc.collect()
# Out:
# 10

# %%
import math
import torch
from torch.optim.lr_scheduler import _LRScheduler
from augment import Mixup, Cutmix
from lr_scheduler import CosineAnnealingWarmupRestarts
from loss import BCEFocalLoss


class BirdModel(pl.LightningModule):
    
    def __init__(self,steps_per_epoch):
        super().__init__()
        
        # == backbone ==
        # self.backbone = EffNet(CONFIG.model, n_classes=len(full_label_list))
        
        # self.backbone = MetaStyleEncoder(128,128,182)
        self.backbone = MyModel()
        self.steps_per_epoch = steps_per_epoch
        # == loss function ==
        self.loss_fn_ce = nn.CrossEntropyLoss()
        self.loss_fn = nn.BCEWithLogitsLoss(reduction="mean")
        self.loss_fn_focal = nn.BCEWithLogitsLoss(reduction="mean")
    
        self.mixup = Mixup(mix_beta=1)
        self.cutmix = Cutmix(1)
        
        # == record ==
        self.validation_step_outputs = []
        
    def forward(self, images):
        return self.backbone(images)
    
    def configure_optimizers(self):
        
        # == define optimizer ==
        model_optimizer = torch.optim.AdamW(
            filter(lambda p: p.requires_grad, self.parameters()),
            lr=CONFIG.lr,
            weight_decay=CONFIG.weight_decay
        )

        # model_optimizer = Adan(self.parameters(), lr=CONFIG.lr, betas=(0.02, 0.08, 0.01), weight_decay=1e-2)
        
        # == define learning rate scheduler ==
        lr_scheduler = CosineAnnealingWarmRestarts(
            model_optimizer,
            T_0=CONFIG.epochs,
            T_mult=1,
            eta_min=1e-6,
            last_epoch=-1
        )

        # lr_scheduler = CosineAnnealingWarmupRestarts(
        #     model_optimizer,
        #     first_cycle_steps= CONFIG.epochs*2,
        #     cycle_mult=CONFIG.epochs,
        #     max_lr= CONFIG.lr,
        #     min_lr=1e-6,
        #     warmup_steps=0,
        #     gamma=1,
        #     last_epoch=-1
        # )
                
        # lr_scheduler = torch.optim.lr_scheduler.OneCycleLR(
        #     optimizer=model_optimizer, epochs=CONFIG.epochs,
        #     pct_start=0.0, steps_per_epoch=self.steps_per_epoch,
        #     max_lr=CONFIG.lr, div_factor=25, final_div_factor=4.0e-01
        # )
        
        return {
            'optimizer': model_optimizer,
            'lr_scheduler': {
                'scheduler': lr_scheduler,
                'interval': 'epoch',
                'monitor': 'val_loss',
                'frequency': 1
            }
        }
    
    def training_step(self, batch, batch_idx):
        
        # == obtain input and target ==
        image, target = batch
        image = image.to(self.device)
        target = target.to(self.device)

        # Perform mixup and cutmix only until epoch 25, after it only adjust to original data
        if(self.current_epoch <= 10):
            pass
        elif(self.current_epoch <= 20):
            # For this exp lets mixup by 3 and cutmix by 1
            # rand_scale = random.uniform(0, 1)
            # if(rand_scale > 0.5):
            for _ in range(2):
                image, target = self.mixup(image, target)
    
            rand_scale = random.uniform(0, 1)
            if(rand_scale > 0.5):
                image, target = self.cutmix(image.unsqueeze(1), target)
                image = image.squeeze(1)
        else:

            rand_scale = random.uniform(0, 1)
            if(rand_scale > 0.5):
                image, target = self.mixup(image, target)
                    
        # == pred ==
        y_pred = self(image)
        
        # == compute loss ==
        train_loss = self.loss_fn(y_pred, target)
        train_loss_focal = self.loss_fn_focal(y_pred[:,:182], target[:,:182])

        # train_loss = train_loss 
        
        # == record ==
        self.log('bce', train_loss, True)
        self.log('182bce', train_loss_focal, True)
        return train_loss + train_loss_focal
    
    def validation_step(self, batch, batch_idx):
        
        # == obtain input and target ==
        image, target = batch
        image = image.to(self.device)
        target = target.to(self.device)
        
        # == pred ==
        with torch.no_grad():
            y_pred = self(image)
            
        self.validation_step_outputs.append({"logits": y_pred, "targets": target})
        
    def train_dataloader(self):
        return self._train_dataloader

    def validation_dataloader(self):
        return self._validation_dataloader
    
    def on_validation_epoch_end(self):
        
        # = merge batch data =
        outputs = self.validation_step_outputs
        
        output_val = nn.Softmax(dim=1)(torch.cat([x['logits'] for x in outputs], dim=0)).cpu().detach()
        target_val = torch.cat([x['targets'] for x in outputs], dim=0).cpu().detach().float()
        
        # target to one-hot
#         target_val = torch.nn.functional.one_hot(target_val, len(label_list)).float()
        
        # = compute validation loss =
        val_loss = self.loss_fn(output_val.to("cuda"), target_val.to("cuda"))
        
        
        target_val = np.ceil(target_val)
        # = val with ROC AUC =
        gt_df = pd.DataFrame(target_val.numpy().astype(np.float32), columns=full_label_list)
        pred_df = pd.DataFrame(output_val.numpy().astype(np.float32), columns=full_label_list)
        
        gt_df['id'] = [f'id_{i}' for i in range(len(gt_df))]
        pred_df['id'] = [f'id_{i}' for i in range(len(pred_df))]
        
        val_score = score(gt_df, pred_df, row_id_column_name='id')
        
        self.log("val_score", val_score, True)
        
        # clear validation outputs
        self.validation_step_outputs = list()
        
        return {'val_loss': val_loss, 'val_score': val_score}

# %%
bird_model = BirdModel(steps_per_epoch = 999)

# %%
bird_model.current_epoch
# Out:
# 0

# %%
model_optimizer = torch.optim.AdamW(
    filter(lambda p: p.requires_grad, MyModel().parameters()),
    lr=CONFIG.lr,
    weight_decay=CONFIG.weight_decay
)

# model_optimizer = Adan(self.parameters(), lr=CONFIG.lr, betas=(0.02, 0.08, 0.01), weight_decay=1e-2)

# == define learning rate scheduler ==
lr_scheduler = CosineAnnealingWarmupRestarts(
    model_optimizer,
    first_cycle_steps=30,
    cycle_mult=30,
    max_lr= CONFIG.lr,
    min_lr=1e-6,
    warmup_steps=0,
    gamma=1,
    last_epoch=-1
)

lrs = []
for i in range(30):
    lrs.append(lr_scheduler.get_lr())
    lr_scheduler.step()

plt.plot(lrs)

# %%
def predict(data_loader, model):
    model.to(CONFIG.device)
    model.eval()
    predictions = []
    gts = []
    for batch in tqdm(data_loader):
        with torch.no_grad():
            x, y = batch
            x = x.cuda()
            outputs = model(x)
            outputs = nn.Softmax(dim=1)(outputs)
        predictions.append(outputs.detach().cpu())
        gts.append(y.detach().cpu())
    
    predictions = torch.cat(predictions, dim=0).cpu().detach()
    gts = torch.cat(gts, dim=0).cpu().detach()
#     gts = torch.nn.functional.one_hot(gts, len(label_list))
    return predictions.numpy().astype(np.float32), gts.numpy().astype(np.float32)

def predict_noised(val_df, model):
    backaud_valid = BackgroundAugmentation(0.1,0.1, ex_df_val, mode = 'eval')
    val_ds = BirdDataset(val_df, backaud_valid, False, get_transforms('valid'), 'valid')
    
    val_dl = torch.utils.data.DataLoader(
        val_ds,
        batch_size=CONFIG.batch_size * 2,
        shuffle=False,
        num_workers=CONFIG.n_workers,
        pin_memory=True,
        persistent_workers=True
    )
    
    mixup = Mixup(mix_beta=1)
    model.to(CONFIG.device)
    model.eval()
    predictions = []
    gts = []
    for batch in tqdm(val_dl):
        with torch.no_grad():
            x, y = batch
            x, y = mixup(x, y)
            x = x.cuda()
            outputs = model(x)
            outputs = nn.Softmax(dim=1)(outputs)
        predictions.append(outputs.detach().cpu())
        gts.append(y.detach().cpu())
    
    predictions = torch.cat(predictions, dim=0).cpu().detach()
    gts = torch.cat(gts, dim=0).cpu().detach()
#     gts = torch.nn.functional.one_hot(gts, len(label_list))
    return predictions.numpy().astype(np.float32), gts.numpy().astype(np.float32)

# %%
def run_training(fold_id, total_df):
    print('================================================================')
    print(f"==== Running training for fold {fold_id} ====")
    
    # == create dataset and dataloader ==
    train_df = total_df[total_df[f'fold'] != fold_id].copy()
    valid_df = total_df[total_df[f'fold'] == fold_id].copy()

    # train_df = train_df[(train_df['rating'] >= 3)|(train_df['volumetry'] < 20)]
    print(f'There are {train_df.primary_label.nunique()} targets')

    
    print(f'Train Samples: {len(train_df)}')
    print(f'Valid Samples: {len(valid_df)}')

    # == create a sampler that samples inversely of its counts ==
    y_train = train_df['target']
    class_sample_count = np.array([len(np.where(y_train == t)[0]) for t in np.unique(y_train)])
    weight = 1. / class_sample_count
    samples_weight = np.array([weight[t] for t in y_train])
    samples_weight = torch.from_numpy(samples_weight)
    
    sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), int(1.3*len(samples_weight)))
    
    
    # backaud = BackgroundAugmentation(0.1,0.3, ex_df_train)
    backaud = None
#     backaud_valid = None
#     backaud_valid = BackgroundAugmentation(0.1,0.1, ex_df)
    
    train_ds = BirdDataset(train_df, None, False, get_transforms('train'), 'train')
    # train_ds = BirdDataset(train_df, backaud, True, None, 'train')
    # val_ds = BirdDataset(valid_df, None, False, get_transforms('valid'), 'valid')
    # train_ds = BirdDataset(train_df, None, False, None, 'train')
    val_ds = BirdDataset(valid_df, None, False, None, 'valid')
    
    train_dl = torch.utils.data.DataLoader(
        train_ds,
        batch_size=CONFIG.batch_size,
        shuffle=False, # If using sampler must be False
        num_workers=CONFIG.n_workers,
        pin_memory=True,
        persistent_workers=True,
        sampler = sampler
    )
    
    val_dl = torch.utils.data.DataLoader(
        val_ds,
        batch_size=CONFIG.batch_size * 2,
        shuffle=False,
        num_workers=CONFIG.n_workers,
        pin_memory=True,
        persistent_workers=True
    )
    
    # == init model ==
    bird_model = BirdModel(steps_per_epoch = len(train_dl))
    # bird_model = BirdModel()

    # Uncomment if fine tuning
    # print('loading pre trained')
    # cpt = torch.load(f'../chpks/30sec_effnet_frompretrained_5sec_samewaveaug_nobackground_overfitting_30epocas/fold_{fold_id}.ckpt', map_location=torch.device('cpu'))['state_dict']
    # bird_model.load_state_dict(cpt)
    # == init callback ==
    checkpoint_callback = ModelCheckpoint(monitor='val_score',
                                          dirpath=CONFIG.checkpoint_dir,
                                          save_top_k=1,
                                          save_last=False,
                                          save_weights_only=True,
                                          filename=f"fold_{fold_id}",
                                          mode='max')
    callbacks_to_use = [checkpoint_callback, TQDMProgressBar(refresh_rate=1)]
    
    # == init trainer ==
    trainer = pl.Trainer(
        max_epochs=CONFIG.epochs,
        val_check_interval=0.5,
        callbacks=callbacks_to_use,
        enable_model_summary=False,
        accelerator="gpu",
        deterministic=False, # Default is True, but it doest not work with metastylespeech
        precision='16-mixed' if CONFIG.mix_precision else 32,
    )
    
    # == Training ==
    trainer.fit(bird_model, train_dataloaders=train_dl, val_dataloaders=val_dl)
    
    # == Prediction ==
    best_model_path = checkpoint_callback.best_model_path
    weights = torch.load(best_model_path)['state_dict']
    bird_model.load_state_dict(weights)
    
    preds, gts = predict(val_dl, bird_model)
    
    # = create dataframe =
    pred_df = pd.DataFrame(preds, columns=full_label_list)
    pred_df = pred_df[label_list]
    pred_df['id'] = np.arange(len(pred_df))
    gt_df = pd.DataFrame(gts, columns=full_label_list)
    gt_df = gt_df[label_list]
    gt_df['id'] = np.arange(len(gt_df))
    
    # = compute score =
    val_score = score(gt_df.apply(np.ceil), pred_df, row_id_column_name='id')
    
    preds_noised, gts_noised = predict_noised(valid_df, bird_model)
    
    # = create dataframe =
    pred_df_noised = pd.DataFrame(preds_noised, columns=full_label_list)
    pred_df_noised = pred_df_noised[label_list]
    pred_df_noised['id'] = np.arange(len(pred_df_noised))
    gt_df_noised = pd.DataFrame(gts_noised, columns=full_label_list)
    gt_df_noised = gt_df_noised[label_list]
    gt_df_noised['id'] = np.arange(len(gt_df_noised))
    
    # = compute score =
    val_score_noised = score(gt_df_noised.apply(np.ceil), pred_df_noised, row_id_column_name='id')

    pd.DataFrame({f'val_noised': [val_score_noised], f'val_clean': [val_score]}).to_csv(f'{CONFIG.checkpoint_dir}/score_fold_{fold_id}.csv', index = False)
    
    # == save to file ==
    pred_cols = [f'pred_{t}' for t in full_label_list]
    valid_df = pd.concat([valid_df.reset_index(), pd.DataFrame(np.zeros((len(valid_df), len(full_label_list)*2)).astype(np.float32), columns=full_label_list+pred_cols)], axis=1)
    valid_df[full_label_list] = gts
    valid_df[pred_cols] = preds
    valid_df.to_csv(f"{CONFIG.checkpoint_dir}/pred_df_f{fold_id}.csv", index=False)
    
    return preds, gts, val_score, val_score_noised

# %%
# training
torch.set_float32_matmul_precision('high')

seed = CONFIG.seed
random.seed(seed)
torch.manual_seed(seed)

# record
fold_val_score_list = list()
fold_val_score_noised_list = list()
oof_df = train_df.copy()
pred_cols = [f'pred_{t}' for t in full_label_list]
oof_df = pd.concat([oof_df, pd.DataFrame(np.zeros((len(oof_df), len(pred_cols)*2)).astype(np.float32), columns=full_label_list+pred_cols)], axis=1)

for f in range(CONFIG.folds):
    
    # get validation index
    val_idx = list(train_df[train_df[f'fold'] == f].index)
    
    # main loop of f-fold
    val_preds, val_gts, val_score, val_score_noised = run_training(f, train_df)
    
    # record
    oof_df.loc[val_idx, full_label_list] = val_gts
    oof_df.loc[val_idx, pred_cols] = val_preds
    fold_val_score_list.append(val_score)
    fold_val_score_noised_list.append(val_score_noised)
    print(f'Fold {f} Val Score: {fold_val_score_list[f]:.5f} Val Score Noised: {fold_val_score_noised_list[f]:.5f}')
    
for idx, val_score in enumerate(fold_val_score_list):
    print(f'Fold {idx} Val Score: {val_score:.5f} Val Score Noised: {fold_val_score_noised_list[idx]:.5f}')

# oof_gt_df = oof_df[['samplename'] + label_list].copy()
# oof_pred_df = oof_df[['samplename'] + pred_cols].copy()
# oof_pred_df.columns = ['samplename'] + label_list
# oof_score = score(oof_gt_df, oof_pred_df, 'samplename')
# print(f'OOF Score: {oof_score:.5f}')

oof_df.to_csv(f"{CONFIG.checkpoint_dir}/oof_pred.csv", index=False)
# Out:
# ================================================================
# ==== Running training for fold 0 ====
# There are 830 targets
# Train Samples: 81563
# Valid Samples: 20391
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Sanity Checking: |                                                                                | 0/? [00:00<?, ?it/s]
# /tmp/ipykernel_95221/2153789775.py:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(input_spec, dtype=torch.float32) ,torch.tensor(target.astype(np.float32))
# /tmp/ipykernel_95221/2153789775.py:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(input_spec, dtype=torch.float32) ,torch.tensor(target.astype(np.float32))
# /tmp/ipykernel_95221/2153789775.py:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(input_spec, dtype=torch.float32) ,torch.tensor(target.astype(np.float32))
# /tmp/ipykernel_95221/2153789775.py:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(input_spec, dtype=torch.float32) ,torch.tensor(target.astype(np.float32))
# Epoch 0:  50%|███████████████               | 1657/3314 [06:17<06:17,  4.39it/s, v_num=113, bce=0.00892, 182bce=0.00811]
# Validation: |                                                                                     | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                                                               | 0/319 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/319 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|▏                                                         | 1/319 [00:00<00:07, 40.46it/s]
# Validation DataLoader 0:   1%|▎                                                         | 2/319 [00:00<00:17, 17.92it/s]
# Validation DataLoader 0:   1%|▌                                                         | 3/319 [00:00<00:17, 17.70it/s]
# Validation DataLoader 0:   1%|▋                                                         | 4/319 [00:00<00:14, 22.11it/s]
# Validation DataLoader 0:   2%|▉                                                         | 5/319 [00:01<01:28,  3.56it/s]
# Validation DataLoader 0:   2%|█                                                         | 6/319 [00:01<01:39,  3.16it/s]
# Validation DataLoader 0:   2%|█▎                                                        | 7/319 [00:01<01:25,  3.65it/s]
# Validation DataLoader 0:   3%|█▍                                                        | 8/319 [00:01<01:14,  4.15it/s]
# Validation DataLoader 0:   3%|█▋                                                        | 9/319 [00:02<01:37,  3.17it/s]
# Validation DataLoader 0:   3%|█▊                                                       | 10/319 [00:03<01:52,  2.75it/s]
# Validation DataLoader 0:   3%|█▉                                                       | 11/319 [00:03<01:42,  3.01it/s]
# Validation DataLoader 0:   4%|██▏                                                      | 12/319 [00:03<01:38,  3.13it/s]
# Validation DataLoader 0:   4%|██▎                                                      | 13/319 [00:04<01:40,  3.04it/s]
# Validation DataLoader 0:   4%|██▌                                                      | 14/319 [00:05<01:57,  2.60it/s]
# Validation DataLoader 0:   5%|██▋                                                      | 15/319 [00:05<01:49,  2.78it/s]
# Validation DataLoader 0:   5%|██▊                                                      | 16/319 [00:05<01:48,  2.79it/s]
# Validation DataLoader 0:   5%|███                                                      | 17/319 [00:05<01:42,  2.96it/s]
# Validation DataLoader 0:   6%|███▏                                                     | 18/319 [00:07<01:58,  2.53it/s]
# Validation DataLoader 0:   6%|███▍                                                     | 19/319 [00:07<01:52,  2.67it/s]
# Validation DataLoader 0:   6%|███▌                                                     | 20/319 [00:07<01:54,  2.62it/s]
# Validation DataLoader 0:   7%|███▊                                                     | 21/319 [00:07<01:48,  2.75it/s]
# Validation DataLoader 0:   7%|███▉                                                     | 22/319 [00:08<01:59,  2.49it/s]
# Validation DataLoader 0:   7%|████                                                     | 23/319 [00:08<01:53,  2.60it/s]
# Validation DataLoader 0:   8%|████▎                                                    | 24/319 [00:09<01:57,  2.51it/s]
# Validation DataLoader 0:   8%|████▍                                                    | 25/319 [00:09<01:52,  2.62it/s]
# Validation DataLoader 0:   8%|████▋                                                    | 26/319 [00:10<01:59,  2.45it/s]
# Validation DataLoader 0:   8%|████▊                                                    | 27/319 [00:10<01:54,  2.55it/s]
# Validation DataLoader 0:   9%|█████                                                    | 28/319 [00:11<01:58,  2.45it/s]
# Validation DataLoader 0:   9%|█████▏                                                   | 29/319 [00:11<01:54,  2.53it/s]
# Validation DataLoader 0:   9%|█████▎                                                   | 30/319 [00:12<01:59,  2.43it/s]
# Validation DataLoader 0:  10%|█████▌                                                   | 31/319 [00:12<01:55,  2.50it/s]
# Validation DataLoader 0:  10%|█████▋                                                   | 32/319 [00:13<01:59,  2.40it/s]
# Validation DataLoader 0:  10%|█████▉                                                   | 33/319 [00:13<01:55,  2.47it/s]
# Validation DataLoader 0:  11%|██████                                                   | 34/319 [00:14<01:58,  2.41it/s]
# Validation DataLoader 0:  11%|██████▎                                                  | 35/319 [00:14<01:54,  2.48it/s]
# Validation DataLoader 0:  11%|██████▍                                                  | 36/319 [00:15<01:59,  2.36it/s]
# Validation DataLoader 0:  12%|██████▌                                                  | 37/319 [00:15<01:56,  2.43it/s]
# Validation DataLoader 0:  12%|██████▊                                                  | 38/319 [00:15<01:57,  2.40it/s]
# Validation DataLoader 0:  12%|██████▉                                                  | 39/319 [00:15<01:53,  2.46it/s]
# Validation DataLoader 0:  13%|███████▏                                                 | 40/319 [00:17<01:58,  2.35it/s]
# Validation DataLoader 0:  13%|███████▎                                                 | 41/319 [00:17<01:55,  2.40it/s]
# Validation DataLoader 0:  13%|███████▌                                                 | 42/319 [00:17<01:56,  2.38it/s]
# Validation DataLoader 0:  13%|███████▋                                                 | 43/319 [00:17<01:53,  2.44it/s]
# Validation DataLoader 0:  14%|███████▊                                                 | 44/319 [00:18<01:57,  2.35it/s]
# Validation DataLoader 0:  14%|████████                                                 | 45/319 [00:18<01:54,  2.40it/s]
# Validation DataLoader 0:  14%|████████▏                                                | 46/319 [00:19<01:55,  2.37it/s]
# Validation DataLoader 0:  15%|████████▍                                                | 47/319 [00:19<01:52,  2.42it/s]
# Validation DataLoader 0:  15%|████████▌                                                | 48/319 [00:20<01:55,  2.34it/s]
# Validation DataLoader 0:  15%|████████▊                                                | 49/319 [00:20<01:52,  2.39it/s]
# Validation DataLoader 0:  16%|████████▉                                                | 50/319 [00:21<01:53,  2.36it/s]
# Validation DataLoader 0:  16%|█████████                                                | 51/319 [00:21<01:51,  2.41it/s]
# Validation DataLoader 0:  16%|█████████▎                                               | 52/319 [00:22<01:54,  2.34it/s]
# Validation DataLoader 0:  17%|█████████▍                                               | 53/319 [00:22<01:51,  2.38it/s]
# Validation DataLoader 0:  17%|█████████▋                                               | 54/319 [00:22<01:52,  2.36it/s]
# Validation DataLoader 0:  17%|█████████▊                                               | 55/319 [00:22<01:49,  2.41it/s]
# Validation DataLoader 0:  18%|██████████                                               | 56/319 [00:23<01:52,  2.34it/s]
# Validation DataLoader 0:  18%|██████████▏                                              | 57/319 [00:23<01:50,  2.38it/s]
# Validation DataLoader 0:  18%|██████████▎                                              | 58/319 [00:24<01:50,  2.36it/s]
# Validation DataLoader 0:  18%|██████████▌                                              | 59/319 [00:24<01:48,  2.40it/s]
# Validation DataLoader 0:  19%|██████████▋                                              | 60/319 [00:25<01:50,  2.34it/s]
# Validation DataLoader 0:  19%|██████████▉                                              | 61/319 [00:25<01:48,  2.37it/s]
# Validation DataLoader 0:  19%|███████████                                              | 62/319 [00:26<01:49,  2.35it/s]
# Validation DataLoader 0:  20%|███████████▎                                             | 63/319 [00:26<01:47,  2.39it/s]
# Validation DataLoader 0:  20%|███████████▍                                             | 64/319 [00:27<01:49,  2.34it/s]
# Validation DataLoader 0:  20%|███████████▌                                             | 65/319 [00:27<01:47,  2.37it/s]
# Validation DataLoader 0:  21%|███████████▊                                             | 66/319 [00:28<01:48,  2.34it/s]
# Validation DataLoader 0:  21%|███████████▉                                             | 67/319 [00:28<01:46,  2.38it/s]
# Validation DataLoader 0:  21%|████████████▏                                            | 68/319 [00:29<01:47,  2.34it/s]
# Validation DataLoader 0:  22%|████████████▎                                            | 69/319 [00:29<01:45,  2.37it/s]
# Validation DataLoader 0:  22%|████████████▌                                            | 70/319 [00:29<01:46,  2.34it/s]
# Validation DataLoader 0:  22%|████████████▋                                            | 71/319 [00:29<01:44,  2.37it/s]
# Validation DataLoader 0:  23%|████████████▊                                            | 72/319 [00:30<01:45,  2.34it/s]
# Validation DataLoader 0:  23%|█████████████                                            | 73/319 [00:30<01:43,  2.37it/s]
# Validation DataLoader 0:  23%|█████████████▏                                           | 74/319 [00:31<01:44,  2.34it/s]
# Validation DataLoader 0:  24%|█████████████▍                                           | 75/319 [00:31<01:42,  2.37it/s]
# Validation DataLoader 0:  24%|█████████████▌                                           | 76/319 [00:32<01:43,  2.35it/s]
# Validation DataLoader 0:  24%|█████████████▊                                           | 77/319 [00:32<01:41,  2.38it/s]
# Validation DataLoader 0:  24%|█████████████▉                                           | 78/319 [00:33<01:43,  2.33it/s]
# Validation DataLoader 0:  25%|██████████████                                           | 79/319 [00:33<01:41,  2.36it/s]
# Validation DataLoader 0:  25%|██████████████▎                                          | 80/319 [00:34<01:42,  2.33it/s]
# Validation DataLoader 0:  25%|██████████████▍                                          | 81/319 [00:34<01:40,  2.36it/s]
# Validation DataLoader 0:  26%|██████████████▋                                          | 82/319 [00:35<01:42,  2.32it/s]
# Validation DataLoader 0:  26%|██████████████▊                                          | 83/319 [00:35<01:40,  2.35it/s]
# Validation DataLoader 0:  26%|███████████████                                          | 84/319 [00:36<01:41,  2.32it/s]
# Validation DataLoader 0:  27%|███████████████▏                                         | 85/319 [00:36<01:39,  2.35it/s]
# Validation DataLoader 0:  27%|███████████████▎                                         | 86/319 [00:37<01:40,  2.31it/s]
# Validation DataLoader 0:  27%|███████████████▌                                         | 87/319 [00:37<01:39,  2.34it/s]
# Validation DataLoader 0:  28%|███████████████▋                                         | 88/319 [00:38<01:39,  2.31it/s]
# Validation DataLoader 0:  28%|███████████████▉                                         | 89/319 [00:38<01:38,  2.34it/s]
# Validation DataLoader 0:  28%|████████████████                                         | 90/319 [00:39<01:39,  2.30it/s]
# Validation DataLoader 0:  29%|████████████████▎                                        | 91/319 [00:39<01:37,  2.33it/s]
# Validation DataLoader 0:  29%|████████████████▍                                        | 92/319 [00:39<01:38,  2.30it/s]
# Validation DataLoader 0:  29%|████████████████▌                                        | 93/319 [00:39<01:37,  2.33it/s]
# Validation DataLoader 0:  29%|████████████████▊                                        | 94/319 [00:40<01:38,  2.29it/s]
# Validation DataLoader 0:  30%|████████████████▉                                        | 95/319 [00:40<01:36,  2.32it/s]
# Validation DataLoader 0:  30%|█████████████████▏                                       | 96/319 [00:41<01:37,  2.30it/s]
# Validation DataLoader 0:  30%|█████████████████▎                                       | 97/319 [00:41<01:35,  2.32it/s]
# Validation DataLoader 0:  31%|█████████████████▌                                       | 98/319 [00:42<01:36,  2.29it/s]
# Validation DataLoader 0:  31%|█████████████████▋                                       | 99/319 [00:42<01:35,  2.31it/s]
# Validation DataLoader 0:  31%|█████████████████▌                                      | 100/319 [00:43<01:35,  2.29it/s]
# Validation DataLoader 0:  32%|█████████████████▋                                      | 101/319 [00:43<01:34,  2.31it/s]
# Validation DataLoader 0:  32%|█████████████████▉                                      | 102/319 [00:44<01:35,  2.28it/s]
# Validation DataLoader 0:  32%|██████████████████                                      | 103/319 [00:44<01:33,  2.30it/s]
# Validation DataLoader 0:  33%|██████████████████▎                                     | 104/319 [00:45<01:33,  2.29it/s]
# Validation DataLoader 0:  33%|██████████████████▍                                     | 105/319 [00:45<01:32,  2.31it/s]
# Validation DataLoader 0:  33%|██████████████████▌                                     | 106/319 [00:46<01:33,  2.28it/s]
# Validation DataLoader 0:  34%|██████████████████▊                                     | 107/319 [00:46<01:32,  2.30it/s]
# Validation DataLoader 0:  34%|██████████████████▉                                     | 108/319 [00:47<01:32,  2.28it/s]
# Validation DataLoader 0:  34%|███████████████████▏                                    | 109/319 [00:47<01:31,  2.30it/s]
# Validation DataLoader 0:  34%|███████████████████▎                                    | 110/319 [00:48<01:32,  2.27it/s]
# Validation DataLoader 0:  35%|███████████████████▍                                    | 111/319 [00:48<01:30,  2.29it/s]
# Validation DataLoader 0:  35%|███████████████████▋                                    | 112/319 [00:49<01:30,  2.28it/s]
# Validation DataLoader 0:  35%|███████████████████▊                                    | 113/319 [00:49<01:29,  2.30it/s]
# Validation DataLoader 0:  36%|████████████████████                                    | 114/319 [00:50<01:30,  2.27it/s]
# Validation DataLoader 0:  36%|████████████████████▏                                   | 115/319 [00:50<01:29,  2.28it/s]
# Validation DataLoader 0:  36%|████████████████████▎                                   | 116/319 [00:51<01:29,  2.27it/s]
# Validation DataLoader 0:  37%|████████████████████▌                                   | 117/319 [00:51<01:28,  2.29it/s]
# Validation DataLoader 0:  37%|████████████████████▋                                   | 118/319 [00:52<01:29,  2.25it/s]
# Validation DataLoader 0:  37%|████████████████████▉                                   | 119/319 [00:52<01:28,  2.27it/s]
# Validation DataLoader 0:  38%|█████████████████████                                   | 120/319 [00:53<01:28,  2.25it/s]
# Validation DataLoader 0:  38%|█████████████████████▏                                  | 121/319 [00:53<01:27,  2.27it/s]
# Validation DataLoader 0:  38%|█████████████████████▍                                  | 122/319 [00:54<01:27,  2.25it/s]
# Validation DataLoader 0:  39%|█████████████████████▌                                  | 123/319 [00:54<01:26,  2.27it/s]
# Validation DataLoader 0:  39%|█████████████████████▊                                  | 124/319 [00:55<01:26,  2.25it/s]
# Validation DataLoader 0:  39%|█████████████████████▉                                  | 125/319 [00:55<01:25,  2.27it/s]
# Validation DataLoader 0:  39%|██████████████████████                                  | 126/319 [00:56<01:25,  2.25it/s]
# Validation DataLoader 0:  40%|██████████████████████▎                                 | 127/319 [00:56<01:24,  2.26it/s]
# Validation DataLoader 0:  40%|██████████████████████▍                                 | 128/319 [00:57<01:25,  2.25it/s]
# Validation DataLoader 0:  40%|██████████████████████▋                                 | 129/319 [00:57<01:23,  2.26it/s]
# Validation DataLoader 0:  41%|██████████████████████▊                                 | 130/319 [00:58<01:24,  2.24it/s]
# Validation DataLoader 0:  41%|██████████████████████▉                                 | 131/319 [00:58<01:23,  2.26it/s]
# Validation DataLoader 0:  41%|███████████████████████▏                                | 132/319 [00:58<01:23,  2.24it/s]
# Validation DataLoader 0:  42%|███████████████████████▎                                | 133/319 [00:58<01:22,  2.26it/s]
# Validation DataLoader 0:  42%|███████████████████████▌                                | 134/319 [00:59<01:22,  2.24it/s]
# Validation DataLoader 0:  42%|███████████████████████▋                                | 135/319 [00:59<01:21,  2.25it/s]
# Validation DataLoader 0:  43%|███████████████████████▊                                | 136/319 [01:00<01:21,  2.23it/s]
# Validation DataLoader 0:  43%|████████████████████████                                | 137/319 [01:00<01:20,  2.25it/s]
# Validation DataLoader 0:  43%|████████████████████████▏                               | 138/319 [01:01<01:21,  2.23it/s]
# Validation DataLoader 0:  44%|████████████████████████▍                               | 139/319 [01:01<01:20,  2.25it/s]
# Validation DataLoader 0:  44%|████████████████████████▌                               | 140/319 [01:02<01:20,  2.23it/s]
# Validation DataLoader 0:  44%|████████████████████████▊                               | 141/319 [01:02<01:19,  2.24it/s]
# Validation DataLoader 0:  45%|████████████████████████▉                               | 142/319 [01:03<01:19,  2.22it/s]
# Validation DataLoader 0:  45%|█████████████████████████                               | 143/319 [01:03<01:18,  2.24it/s]
# Validation DataLoader 0:  45%|█████████████████████████▎                              | 144/319 [01:04<01:18,  2.22it/s]
# Validation DataLoader 0:  45%|█████████████████████████▍                              | 145/319 [01:04<01:17,  2.24it/s]
# Validation DataLoader 0:  46%|█████████████████████████▋                              | 146/319 [01:05<01:18,  2.21it/s]
# Validation DataLoader 0:  46%|█████████████████████████▊                              | 147/319 [01:05<01:17,  2.23it/s]
# Validation DataLoader 0:  46%|█████████████████████████▉                              | 148/319 [01:06<01:17,  2.22it/s]
# Validation DataLoader 0:  47%|██████████████████████████▏                             | 149/319 [01:06<01:16,  2.23it/s]
# Validation DataLoader 0:  47%|██████████████████████████▎                             | 150/319 [01:08<01:16,  2.20it/s]
# Validation DataLoader 0:  47%|██████████████████████████▌                             | 151/319 [01:08<01:15,  2.22it/s]
# Validation DataLoader 0:  48%|██████████████████████████▋                             | 152/319 [01:08<01:15,  2.21it/s]
# Validation DataLoader 0:  48%|██████████████████████████▊                             | 153/319 [01:08<01:14,  2.23it/s]
# Validation DataLoader 0:  48%|███████████████████████████                             | 154/319 [01:10<01:15,  2.20it/s]
# Validation DataLoader 0:  49%|███████████████████████████▏                            | 155/319 [01:10<01:14,  2.21it/s]
# Validation DataLoader 0:  49%|███████████████████████████▍                            | 156/319 [01:10<01:13,  2.20it/s]
# Validation DataLoader 0:  49%|███████████████████████████▌                            | 157/319 [01:10<01:13,  2.22it/s]
# Validation DataLoader 0:  50%|███████████████████████████▋                            | 158/319 [01:11<01:13,  2.19it/s]
# Validation DataLoader 0:  50%|███████████████████████████▉                            | 159/319 [01:11<01:12,  2.21it/s]
# Validation DataLoader 0:  50%|████████████████████████████                            | 160/319 [01:12<01:12,  2.20it/s]
# Validation DataLoader 0:  50%|████████████████████████████▎                           | 161/319 [01:12<01:11,  2.22it/s]
# Validation DataLoader 0:  51%|████████████████████████████▍                           | 162/319 [01:13<01:11,  2.20it/s]
# Validation DataLoader 0:  51%|████████████████████████████▌                           | 163/319 [01:13<01:10,  2.21it/s]
# Validation DataLoader 0:  51%|████████████████████████████▊                           | 164/319 [01:14<01:10,  2.21it/s]
# Validation DataLoader 0:  52%|████████████████████████████▉                           | 165/319 [01:14<01:09,  2.22it/s]
# Validation DataLoader 0:  52%|█████████████████████████████▏                          | 166/319 [01:15<01:09,  2.20it/s]
# Validation DataLoader 0:  52%|█████████████████████████████▎                          | 167/319 [01:15<01:08,  2.21it/s]
# Validation DataLoader 0:  53%|█████████████████████████████▍                          | 168/319 [01:16<01:08,  2.20it/s]
# Validation DataLoader 0:  53%|█████████████████████████████▋                          | 169/319 [01:16<01:07,  2.22it/s]
# Validation DataLoader 0:  53%|█████████████████████████████▊                          | 170/319 [01:17<01:07,  2.20it/s]
# Validation DataLoader 0:  54%|██████████████████████████████                          | 171/319 [01:17<01:06,  2.21it/s]
# Validation DataLoader 0:  54%|██████████████████████████████▏                         | 172/319 [01:18<01:06,  2.20it/s]
# Validation DataLoader 0:  54%|██████████████████████████████▎                         | 173/319 [01:18<01:06,  2.21it/s]
# Validation DataLoader 0:  55%|██████████████████████████████▌                         | 174/319 [01:19<01:06,  2.19it/s]
# Validation DataLoader 0:  55%|██████████████████████████████▋                         | 175/319 [01:19<01:05,  2.21it/s]
# Validation DataLoader 0:  55%|██████████████████████████████▉                         | 176/319 [01:20<01:05,  2.19it/s]
# Validation DataLoader 0:  55%|███████████████████████████████                         | 177/319 [01:20<01:04,  2.21it/s]
# Validation DataLoader 0:  56%|███████████████████████████████▏                        | 178/319 [01:21<01:04,  2.19it/s]
# Validation DataLoader 0:  56%|███████████████████████████████▍                        | 179/319 [01:21<01:03,  2.20it/s]
# Validation DataLoader 0:  56%|███████████████████████████████▌                        | 180/319 [01:22<01:03,  2.19it/s]
# Validation DataLoader 0:  57%|███████████████████████████████▊                        | 181/319 [01:22<01:02,  2.20it/s]
# Validation DataLoader 0:  57%|███████████████████████████████▉                        | 182/319 [01:23<01:02,  2.18it/s]
# Validation DataLoader 0:  57%|████████████████████████████████▏                       | 183/319 [01:23<01:01,  2.20it/s]
# Validation DataLoader 0:  58%|████████████████████████████████▎                       | 184/319 [01:24<01:01,  2.19it/s]
# Validation DataLoader 0:  58%|████████████████████████████████▍                       | 185/319 [01:24<01:00,  2.20it/s]
# Validation DataLoader 0:  58%|████████████████████████████████▋                       | 186/319 [01:25<01:01,  2.18it/s]
# Validation DataLoader 0:  59%|████████████████████████████████▊                       | 187/319 [01:25<01:00,  2.19it/s]
# Validation DataLoader 0:  59%|█████████████████████████████████                       | 188/319 [01:26<00:59,  2.19it/s]
# Validation DataLoader 0:  59%|█████████████████████████████████▏                      | 189/319 [01:26<00:59,  2.20it/s]
# Validation DataLoader 0:  60%|█████████████████████████████████▎                      | 190/319 [01:27<00:59,  2.17it/s]
# Validation DataLoader 0:  60%|█████████████████████████████████▌                      | 191/319 [01:27<00:58,  2.18it/s]
# Validation DataLoader 0:  60%|█████████████████████████████████▋                      | 192/319 [01:27<00:58,  2.18it/s]
# Validation DataLoader 0:  61%|█████████████████████████████████▉                      | 193/319 [01:27<00:57,  2.19it/s]
# Validation DataLoader 0:  61%|██████████████████████████████████                      | 194/319 [01:29<00:57,  2.17it/s]
# Validation DataLoader 0:  61%|██████████████████████████████████▏                     | 195/319 [01:29<00:56,  2.18it/s]
# Validation DataLoader 0:  61%|██████████████████████████████████▍                     | 196/319 [01:29<00:56,  2.18it/s]
# Validation DataLoader 0:  62%|██████████████████████████████████▌                     | 197/319 [01:29<00:55,  2.19it/s]
# Validation DataLoader 0:  62%|██████████████████████████████████▊                     | 198/319 [01:31<00:55,  2.17it/s]
# Validation DataLoader 0:  62%|██████████████████████████████████▉                     | 199/319 [01:31<00:54,  2.18it/s]
# Validation DataLoader 0:  63%|███████████████████████████████████                     | 200/319 [01:31<00:54,  2.18it/s]
# Validation DataLoader 0:  63%|███████████████████████████████████▎                    | 201/319 [01:31<00:53,  2.19it/s]
# Validation DataLoader 0:  63%|███████████████████████████████████▍                    | 202/319 [01:33<00:53,  2.17it/s]
# Validation DataLoader 0:  64%|███████████████████████████████████▋                    | 203/319 [01:33<00:53,  2.18it/s]
# Validation DataLoader 0:  64%|███████████████████████████████████▊                    | 204/319 [01:33<00:52,  2.18it/s]
# Validation DataLoader 0:  64%|███████████████████████████████████▉                    | 205/319 [01:33<00:52,  2.19it/s]
# Validation DataLoader 0:  65%|████████████████████████████████████▏                   | 206/319 [01:34<00:52,  2.17it/s]
# Validation DataLoader 0:  65%|████████████████████████████████████▎                   | 207/319 [01:34<00:51,  2.18it/s]
# Validation DataLoader 0:  65%|████████████████████████████████████▌                   | 208/319 [01:35<00:50,  2.18it/s]
# Validation DataLoader 0:  66%|████████████████████████████████████▋                   | 209/319 [01:35<00:50,  2.19it/s]
# Validation DataLoader 0:  66%|████████████████████████████████████▊                   | 210/319 [01:36<00:50,  2.17it/s]
# Validation DataLoader 0:  66%|█████████████████████████████████████                   | 211/319 [01:36<00:49,  2.18it/s]
# Validation DataLoader 0:  66%|█████████████████████████████████████▏                  | 212/319 [01:37<00:49,  2.18it/s]
# Validation DataLoader 0:  67%|█████████████████████████████████████▍                  | 213/319 [01:37<00:48,  2.19it/s]
# Validation DataLoader 0:  67%|█████████████████████████████████████▌                  | 214/319 [01:38<00:48,  2.17it/s]
# Validation DataLoader 0:  67%|█████████████████████████████████████▋                  | 215/319 [01:38<00:47,  2.18it/s]
# Validation DataLoader 0:  68%|█████████████████████████████████████▉                  | 216/319 [01:39<00:47,  2.18it/s]
# Validation DataLoader 0:  68%|██████████████████████████████████████                  | 217/319 [01:39<00:46,  2.19it/s]
# Validation DataLoader 0:  68%|██████████████████████████████████████▎                 | 218/319 [01:40<00:46,  2.17it/s]
# Validation DataLoader 0:  69%|██████████████████████████████████████▍                 | 219/319 [01:40<00:45,  2.18it/s]
# Validation DataLoader 0:  69%|██████████████████████████████████████▌                 | 220/319 [01:41<00:45,  2.18it/s]
# Validation DataLoader 0:  69%|██████████████████████████████████████▊                 | 221/319 [01:41<00:44,  2.19it/s]
# Validation DataLoader 0:  70%|██████████████████████████████████████▉                 | 222/319 [01:42<00:44,  2.16it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▏                | 223/319 [01:42<00:44,  2.17it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▎                | 224/319 [01:42<00:43,  2.18it/s]
# Validation DataLoader 0:  71%|███████████████████████████████████████▍                | 225/319 [01:42<00:42,  2.19it/s]
# Validation DataLoader 0:  71%|███████████████████████████████████████▋                | 226/319 [01:44<00:43,  2.16it/s]
# Validation DataLoader 0:  71%|███████████████████████████████████████▊                | 227/319 [01:44<00:42,  2.17it/s]
# Validation DataLoader 0:  71%|████████████████████████████████████████                | 228/319 [01:44<00:41,  2.18it/s]
# Validation DataLoader 0:  72%|████████████████████████████████████████▏               | 229/319 [01:44<00:41,  2.19it/s]
# Validation DataLoader 0:  72%|████████████████████████████████████████▍               | 230/319 [01:46<00:41,  2.16it/s]
# Validation DataLoader 0:  72%|████████████████████████████████████████▌               | 231/319 [01:46<00:40,  2.17it/s]
# Validation DataLoader 0:  73%|████████████████████████████████████████▋               | 232/319 [01:46<00:39,  2.18it/s]
# Validation DataLoader 0:  73%|████████████████████████████████████████▉               | 233/319 [01:46<00:39,  2.19it/s]
# Validation DataLoader 0:  73%|█████████████████████████████████████████               | 234/319 [01:48<00:39,  2.16it/s]
# Validation DataLoader 0:  74%|█████████████████████████████████████████▎              | 235/319 [01:48<00:38,  2.17it/s]
# Validation DataLoader 0:  74%|█████████████████████████████████████████▍              | 236/319 [01:48<00:38,  2.17it/s]
# Validation DataLoader 0:  74%|█████████████████████████████████████████▌              | 237/319 [01:48<00:37,  2.18it/s]
# Validation DataLoader 0:  75%|█████████████████████████████████████████▊              | 238/319 [01:50<00:37,  2.16it/s]
# Validation DataLoader 0:  75%|█████████████████████████████████████████▉              | 239/319 [01:50<00:36,  2.17it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▏             | 240/319 [01:50<00:36,  2.17it/s]
# Validation DataLoader 0:  76%|██████████████████████████████████████████▎             | 241/319 [01:50<00:35,  2.18it/s]
# Validation DataLoader 0:  76%|██████████████████████████████████████████▍             | 242/319 [01:52<00:35,  2.16it/s]
# Validation DataLoader 0:  76%|██████████████████████████████████████████▋             | 243/319 [01:52<00:35,  2.17it/s]
# Validation DataLoader 0:  76%|██████████████████████████████████████████▊             | 244/319 [01:52<00:34,  2.17it/s]
# Validation DataLoader 0:  77%|███████████████████████████████████████████             | 245/319 [01:52<00:33,  2.18it/s]
# Validation DataLoader 0:  77%|███████████████████████████████████████████▏            | 246/319 [01:53<00:33,  2.16it/s]
# Validation DataLoader 0:  77%|███████████████████████████████████████████▎            | 247/319 [01:54<00:33,  2.17it/s]
# Validation DataLoader 0:  78%|███████████████████████████████████████████▌            | 248/319 [01:54<00:32,  2.17it/s]
# Validation DataLoader 0:  78%|███████████████████████████████████████████▋            | 249/319 [01:54<00:32,  2.18it/s]
# Validation DataLoader 0:  78%|███████████████████████████████████████████▉            | 250/319 [01:55<00:31,  2.16it/s]
# Validation DataLoader 0:  79%|████████████████████████████████████████████            | 251/319 [01:55<00:31,  2.17it/s]
# Validation DataLoader 0:  79%|████████████████████████████████████████████▏           | 252/319 [01:55<00:30,  2.17it/s]
# Validation DataLoader 0:  79%|████████████████████████████████████████████▍           | 253/319 [01:55<00:30,  2.18it/s]
# Validation DataLoader 0:  80%|████████████████████████████████████████████▌           | 254/319 [01:57<00:30,  2.16it/s]
# Validation DataLoader 0:  80%|████████████████████████████████████████████▊           | 255/319 [01:57<00:29,  2.17it/s]
# Validation DataLoader 0:  80%|████████████████████████████████████████████▉           | 256/319 [01:57<00:28,  2.18it/s]
# Validation DataLoader 0:  81%|█████████████████████████████████████████████           | 257/319 [01:57<00:28,  2.18it/s]
# Validation DataLoader 0:  81%|█████████████████████████████████████████████▎          | 258/319 [01:59<00:28,  2.16it/s]
# Validation DataLoader 0:  81%|█████████████████████████████████████████████▍          | 259/319 [01:59<00:27,  2.17it/s]
# Validation DataLoader 0:  82%|█████████████████████████████████████████████▋          | 260/319 [01:59<00:27,  2.18it/s]
# Validation DataLoader 0:  82%|█████████████████████████████████████████████▊          | 261/319 [01:59<00:26,  2.18it/s]
# Validation DataLoader 0:  82%|█████████████████████████████████████████████▉          | 262/319 [02:01<00:26,  2.16it/s]
# Validation DataLoader 0:  82%|██████████████████████████████████████████████▏         | 263/319 [02:01<00:25,  2.17it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████████████▎         | 264/319 [02:01<00:25,  2.17it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████████████▌         | 265/319 [02:01<00:24,  2.18it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████████████▋         | 266/319 [02:03<00:24,  2.16it/s]
# Validation DataLoader 0:  84%|██████████████████████████████████████████████▊         | 267/319 [02:03<00:23,  2.17it/s]
# Validation DataLoader 0:  84%|███████████████████████████████████████████████         | 268/319 [02:03<00:23,  2.17it/s]
# Validation DataLoader 0:  84%|███████████████████████████████████████████████▏        | 269/319 [02:03<00:22,  2.18it/s]
# Validation DataLoader 0:  85%|███████████████████████████████████████████████▍        | 270/319 [02:04<00:22,  2.16it/s]
# Validation DataLoader 0:  85%|███████████████████████████████████████████████▌        | 271/319 [02:04<00:22,  2.17it/s]
# Validation DataLoader 0:  85%|███████████████████████████████████████████████▋        | 272/319 [02:05<00:21,  2.18it/s]
# Validation DataLoader 0:  86%|███████████████████████████████████████████████▉        | 273/319 [02:05<00:21,  2.18it/s]
# Validation DataLoader 0:  86%|████████████████████████████████████████████████        | 274/319 [02:06<00:20,  2.16it/s]
# Validation DataLoader 0:  86%|████████████████████████████████████████████████▎       | 275/319 [02:06<00:20,  2.17it/s]
# Validation DataLoader 0:  87%|████████████████████████████████████████████████▍       | 276/319 [02:06<00:19,  2.17it/s]
# Validation DataLoader 0:  87%|████████████████████████████████████████████████▋       | 277/319 [02:06<00:19,  2.18it/s]
# Validation DataLoader 0:  87%|████████████████████████████████████████████████▊       | 278/319 [02:08<00:18,  2.16it/s]
# Validation DataLoader 0:  87%|████████████████████████████████████████████████▉       | 279/319 [02:08<00:18,  2.17it/s]
# Validation DataLoader 0:  88%|█████████████████████████████████████████████████▏      | 280/319 [02:08<00:17,  2.17it/s]
# Validation DataLoader 0:  88%|█████████████████████████████████████████████████▎      | 281/319 [02:08<00:17,  2.18it/s]
# Validation DataLoader 0:  88%|█████████████████████████████████████████████████▌      | 282/319 [02:10<00:17,  2.16it/s]
# Validation DataLoader 0:  89%|█████████████████████████████████████████████████▋      | 283/319 [02:10<00:16,  2.17it/s]
# Validation DataLoader 0:  89%|█████████████████████████████████████████████████▊      | 284/319 [02:10<00:16,  2.17it/s]
# Validation DataLoader 0:  89%|██████████████████████████████████████████████████      | 285/319 [02:10<00:15,  2.18it/s]
# Validation DataLoader 0:  90%|██████████████████████████████████████████████████▏     | 286/319 [02:12<00:15,  2.16it/s]
# Validation DataLoader 0:  90%|██████████████████████████████████████████████████▍     | 287/319 [02:12<00:14,  2.17it/s]
# Validation DataLoader 0:  90%|██████████████████████████████████████████████████▌     | 288/319 [02:12<00:14,  2.17it/s]
# Validation DataLoader 0:  91%|██████████████████████████████████████████████████▋     | 289/319 [02:12<00:13,  2.18it/s]
# Validation DataLoader 0:  91%|██████████████████████████████████████████████████▉     | 290/319 [02:14<00:13,  2.16it/s]
# Validation DataLoader 0:  91%|███████████████████████████████████████████████████     | 291/319 [02:14<00:12,  2.17it/s]
# Validation DataLoader 0:  92%|███████████████████████████████████████████████████▎    | 292/319 [02:14<00:12,  2.17it/s]
# Validation DataLoader 0:  92%|███████████████████████████████████████████████████▍    | 293/319 [02:14<00:11,  2.18it/s]
# Validation DataLoader 0:  92%|███████████████████████████████████████████████████▌    | 294/319 [02:16<00:11,  2.16it/s]
# Validation DataLoader 0:  92%|███████████████████████████████████████████████████▊    | 295/319 [02:16<00:11,  2.17it/s]
# Validation DataLoader 0:  93%|███████████████████████████████████████████████████▉    | 296/319 [02:16<00:10,  2.17it/s]
# Validation DataLoader 0:  93%|████████████████████████████████████████████████████▏   | 297/319 [02:16<00:10,  2.18it/s]
# Validation DataLoader 0:  93%|████████████████████████████████████████████████████▎   | 298/319 [02:18<00:09,  2.16it/s]
# Validation DataLoader 0:  94%|████████████████████████████████████████████████████▍   | 299/319 [02:18<00:09,  2.17it/s]
# Validation DataLoader 0:  94%|████████████████████████████████████████████████████▋   | 300/319 [02:18<00:08,  2.17it/s]
# Validation DataLoader 0:  94%|████████████████████████████████████████████████████▊   | 301/319 [02:18<00:08,  2.18it/s]
# Validation DataLoader 0:  95%|█████████████████████████████████████████████████████   | 302/319 [02:19<00:07,  2.16it/s]
# Validation DataLoader 0:  95%|█████████████████████████████████████████████████████▏  | 303/319 [02:19<00:07,  2.17it/s]
# Validation DataLoader 0:  95%|█████████████████████████████████████████████████████▎  | 304/319 [02:19<00:06,  2.17it/s]
# Validation DataLoader 0:  96%|█████████████████████████████████████████████████████▌  | 305/319 [02:19<00:06,  2.18it/s]
# Validation DataLoader 0:  96%|█████████████████████████████████████████████████████▋  | 306/319 [02:21<00:06,  2.16it/s]
# Validation DataLoader 0:  96%|█████████████████████████████████████████████████████▉  | 307/319 [02:21<00:05,  2.17it/s]
# Validation DataLoader 0:  97%|██████████████████████████████████████████████████████  | 308/319 [02:21<00:05,  2.18it/s]
# Validation DataLoader 0:  97%|██████████████████████████████████████████████████████▏ | 309/319 [02:21<00:04,  2.18it/s]
# Validation DataLoader 0:  97%|██████████████████████████████████████████████████████▍ | 310/319 [02:23<00:04,  2.16it/s]
# Validation DataLoader 0:  97%|██████████████████████████████████████████████████████▌ | 311/319 [02:23<00:03,  2.17it/s]
# Validation DataLoader 0:  98%|██████████████████████████████████████████████████████▊ | 312/319 [02:23<00:03,  2.18it/s]
# Validation DataLoader 0:  98%|██████████████████████████████████████████████████████▉ | 313/319 [02:23<00:02,  2.18it/s]
# Validation DataLoader 0:  98%|███████████████████████████████████████████████████████ | 314/319 [02:25<00:02,  2.16it/s]
# Validation DataLoader 0:  99%|███████████████████████████████████████████████████████▎| 315/319 [02:25<00:01,  2.17it/s]
# Validation DataLoader 0:  99%|███████████████████████████████████████████████████████▍| 316/319 [02:25<00:01,  2.18it/s]
# Validation DataLoader 0:  99%|███████████████████████████████████████████████████████▋| 317/319 [02:25<00:00,  2.18it/s]
# Validation DataLoader 0: 100%|███████████████████████████████████████████████████████▊| 318/319 [02:26<00:00,  2.16it/s]
# Validation DataLoader 0: 100%|████████████████████████████████████████████████████████| 319/319 [02:26<00:00,  2.17it/s]
# Epoch 0: 100%|██████████████| 3314/3314 [15:21<00:00,  3.60it/s, v_num=113, bce=0.00769, 182bce=0.0028, val_score=0.824]
# Validation: |                                                                                     | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                                                               | 0/319 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/319 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|▏                                                         | 1/319 [00:00<00:05, 56.11it/s]
# Validation DataLoader 0:   1%|▎                                                         | 2/319 [00:00<00:57,  5.47it/s]
# Validation DataLoader 0:   1%|▌                                                         | 3/319 [00:00<00:39,  7.92it/s]
# Validation DataLoader 0:   1%|▋                                                         | 4/319 [00:00<00:39,  7.88it/s]
# Validation DataLoader 0:   2%|▉                                                         | 5/319 [00:01<01:27,  3.59it/s]
# Validation DataLoader 0:   2%|█                                                         | 6/319 [00:02<01:51,  2.81it/s]
# Validation DataLoader 0:   2%|█▎                                                        | 7/319 [00:02<01:38,  3.16it/s]
# Validation DataLoader 0:   3%|█▍                                                        | 8/319 [00:02<01:33,  3.31it/s]
# Validation DataLoader 0:   3%|█▋                                                        | 9/319 [00:02<01:36,  3.20it/s]
# Validation DataLoader 0:   3%|█▊                                                       | 10/319 [00:04<02:05,  2.47it/s]
# Validation DataLoader 0:   3%|█▉                                                       | 11/319 [00:04<01:54,  2.69it/s]
# Validation DataLoader 0:   4%|██▏                                                      | 12/319 [00:04<01:49,  2.80it/s]
# Validation DataLoader 0:   4%|██▎                                                      | 13/319 [00:04<01:41,  3.02it/s]
# Validation DataLoader 0:   4%|██▌                                                      | 14/319 [00:05<02:07,  2.39it/s]
# Validation DataLoader 0:   5%|██▋                                                      | 15/319 [00:05<02:01,  2.51it/s]
# Validation DataLoader 0:   5%|██▊                                                      | 16/319 [00:06<01:58,  2.55it/s]
# Validation DataLoader 0:   5%|███                                                      | 17/319 [00:06<01:51,  2.70it/s]
# Validation DataLoader 0:   6%|███▏                                                     | 18/319 [00:07<02:07,  2.36it/s]
# Validation DataLoader 0:   6%|███▍                                                     | 19/319 [00:07<02:02,  2.45it/s]
# Validation DataLoader 0:   6%|███▌                                                     | 20/319 [00:07<01:58,  2.53it/s]
# Validation DataLoader 0:   7%|███▊                                                     | 21/319 [00:07<01:52,  2.65it/s]
# Validation DataLoader 0:   7%|███▉                                                     | 22/319 [00:09<02:06,  2.35it/s]
# Validation DataLoader 0:   7%|████                                                     | 23/319 [00:09<02:02,  2.41it/s]
# Validation DataLoader 0:   8%|████▎                                                    | 24/319 [00:09<01:57,  2.52it/s]
# Validation DataLoader 0:   8%|████▍                                                    | 25/319 [00:09<01:52,  2.62it/s]
# Validation DataLoader 0:   8%|████▋                                                    | 26/319 [00:11<02:05,  2.34it/s]
# Validation DataLoader 0:   8%|████▊                                                    | 27/319 [00:11<02:02,  2.38it/s]
# Validation DataLoader 0:   9%|█████                                                    | 28/319 [00:11<01:57,  2.47it/s]
# Validation DataLoader 0:   9%|█████▏                                                   | 29/319 [00:11<01:53,  2.55it/s]
# Validation DataLoader 0:   9%|█████▎                                                   | 30/319 [00:12<02:04,  2.32it/s]
# Validation DataLoader 0:  10%|█████▌                                                   | 31/319 [00:13<02:01,  2.37it/s]
# Validation DataLoader 0:  10%|█████▋                                                   | 32/319 [00:13<01:57,  2.44it/s]
# Validation DataLoader 0:  10%|█████▉                                                   | 33/319 [00:13<01:53,  2.52it/s]
# Validation DataLoader 0:  11%|██████                                                   | 34/319 [00:14<02:03,  2.31it/s]
# Validation DataLoader 0:  11%|██████▎                                                  | 35/319 [00:14<02:00,  2.35it/s]
# Validation DataLoader 0:  11%|██████▍                                                  | 36/319 [00:14<01:57,  2.42it/s]
# Validation DataLoader 0:  12%|██████▌                                                  | 37/319 [00:14<01:53,  2.48it/s]
# Validation DataLoader 0:  12%|██████▊                                                  | 38/319 [00:16<02:01,  2.31it/s]
# Validation DataLoader 0:  12%|██████▉                                                  | 39/319 [00:16<01:59,  2.34it/s]
# Validation DataLoader 0:  13%|███████▏                                                 | 40/319 [00:16<01:56,  2.40it/s]
# Validation DataLoader 0:  13%|███████▎                                                 | 41/319 [00:16<01:53,  2.46it/s]
# Validation DataLoader 0:  13%|███████▌                                                 | 42/319 [00:18<01:59,  2.31it/s]
# Validation DataLoader 0:  13%|███████▋                                                 | 43/319 [00:18<01:58,  2.33it/s]
# Validation DataLoader 0:  14%|███████▊                                                 | 44/319 [00:18<01:55,  2.39it/s]
# Validation DataLoader 0:  14%|████████                                                 | 45/319 [00:18<01:52,  2.44it/s]
# Validation DataLoader 0:  14%|████████▏                                                | 46/319 [00:19<01:58,  2.31it/s]
# Validation DataLoader 0:  15%|████████▍                                                | 47/319 [00:20<01:56,  2.33it/s]
# Validation DataLoader 0:  15%|████████▌                                                | 48/319 [00:20<01:53,  2.38it/s]
# Validation DataLoader 0:  15%|████████▊                                                | 49/319 [00:20<01:51,  2.43it/s]
# Validation DataLoader 0:  16%|████████▉                                                | 50/319 [00:21<01:56,  2.31it/s]
# Validation DataLoader 0:  16%|█████████                                                | 51/319 [00:21<01:55,  2.33it/s]
# Validation DataLoader 0:  16%|█████████▎                                               | 52/319 [00:21<01:52,  2.37it/s]
# Validation DataLoader 0:  17%|█████████▍                                               | 53/319 [00:21<01:50,  2.42it/s]
# Validation DataLoader 0:  17%|█████████▋                                               | 54/319 [00:23<01:54,  2.31it/s]
# ...
# Validation DataLoader 0:  59%|█████████████████████████████████▏                      | 189/319 [01:17<00:53,  2.43it/s]
# Validation DataLoader 0:  60%|█████████████████████████████████▎                      | 190/319 [01:19<00:53,  2.39it/s]
# Validation DataLoader 0:  60%|█████████████████████████████████▌                      | 191/319 [01:19<00:53,  2.40it/s]
# Validation DataLoader 0:  60%|█████████████████████████████████▋                      | 192/319 [01:19<00:52,  2.42it/s]
# Validation DataLoader 0:  61%|█████████████████████████████████▉                      | 193/319 [01:19<00:51,  2.43it/s]
# Validation DataLoader 0:  61%|██████████████████████████████████                      | 194/319 [01:21<00:52,  2.39it/s]
# Validation DataLoader 0:  61%|██████████████████████████████████▏                     | 195/319 [01:21<00:51,  2.40it/s]
# Validation DataLoader 0:  61%|██████████████████████████████████▍                     | 196/319 [01:21<00:50,  2.42it/s]
# Validation DataLoader 0:  62%|██████████████████████████████████▌                     | 197/319 [01:21<00:50,  2.43it/s]
# Validation DataLoader 0:  62%|██████████████████████████████████▊                     | 198/319 [01:22<00:50,  2.39it/s]
# Validation DataLoader 0:  62%|██████████████████████████████████▉                     | 199/319 [01:22<00:49,  2.40it/s]
# Validation DataLoader 0:  63%|███████████████████████████████████                     | 200/319 [01:22<00:49,  2.41it/s]
# Validation DataLoader 0:  63%|███████████████████████████████████▎                    | 201/319 [01:22<00:48,  2.42it/s]
# Validation DataLoader 0:  63%|███████████████████████████████████▍                    | 202/319 [01:24<00:48,  2.39it/s]
# Validation DataLoader 0:  64%|███████████████████████████████████▋                    | 203/319 [01:24<00:48,  2.40it/s]
# Validation DataLoader 0:  64%|███████████████████████████████████▊                    | 204/319 [01:24<00:47,  2.41it/s]
# Validation DataLoader 0:  64%|███████████████████████████████████▉                    | 205/319 [01:24<00:47,  2.42it/s]
# Validation DataLoader 0:  65%|████████████████████████████████████▏                   | 206/319 [01:26<00:47,  2.39it/s]
# Validation DataLoader 0:  65%|████████████████████████████████████▎                   | 207/319 [01:26<00:46,  2.40it/s]
# Validation DataLoader 0:  65%|████████████████████████████████████▌                   | 208/319 [01:26<00:46,  2.41it/s]
# Validation DataLoader 0:  66%|████████████████████████████████████▋                   | 209/319 [01:26<00:45,  2.42it/s]
# Validation DataLoader 0:  66%|████████████████████████████████████▊                   | 210/319 [01:27<00:45,  2.39it/s]
# Validation DataLoader 0:  66%|█████████████████████████████████████                   | 211/319 [01:27<00:45,  2.40it/s]
# Validation DataLoader 0:  66%|█████████████████████████████████████▏                  | 212/319 [01:27<00:44,  2.41it/s]
# Validation DataLoader 0:  67%|█████████████████████████████████████▍                  | 213/319 [01:27<00:43,  2.42it/s]
# Validation DataLoader 0:  67%|█████████████████████████████████████▌                  | 214/319 [01:29<00:43,  2.39it/s]
# Validation DataLoader 0:  67%|█████████████████████████████████████▋                  | 215/319 [01:29<00:43,  2.40it/s]
# Validation DataLoader 0:  68%|█████████████████████████████████████▉                  | 216/319 [01:29<00:42,  2.41it/s]
# Validation DataLoader 0:  68%|██████████████████████████████████████                  | 217/319 [01:29<00:42,  2.42it/s]
# Validation DataLoader 0:  68%|██████████████████████████████████████▎                 | 218/319 [01:31<00:42,  2.38it/s]
# Validation DataLoader 0:  69%|██████████████████████████████████████▍                 | 219/319 [01:31<00:41,  2.39it/s]
# Validation DataLoader 0:  69%|██████████████████████████████████████▌                 | 220/319 [01:31<00:41,  2.40it/s]
# Validation DataLoader 0:  69%|██████████████████████████████████████▊                 | 221/319 [01:31<00:40,  2.41it/s]
# Validation DataLoader 0:  70%|██████████████████████████████████████▉                 | 222/319 [01:33<00:40,  2.38it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▏                | 223/319 [01:33<00:40,  2.39it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▎                | 224/319 [01:33<00:39,  2.40it/s]
# Validation DataLoader 0:  71%|███████████████████████████████████████▍                | 225/319 [01:33<00:38,  2.41it/s]
# Validation DataLoader 0:  71%|███████████████████████████████████████▋                | 226/319 [01:34<00:39,  2.38it/s]
# Validation DataLoader 0:  71%|███████████████████████████████████████▊                | 227/319 [01:34<00:38,  2.39it/s]
# Validation DataLoader 0:  71%|████████████████████████████████████████                | 228/319 [01:34<00:37,  2.40it/s]
# Validation DataLoader 0:  72%|████████████████████████████████████████▏               | 229/319 [01:34<00:37,  2.41it/s]
# Validation DataLoader 0:  72%|████████████████████████████████████████▍               | 230/319 [01:36<00:37,  2.38it/s]
# Validation DataLoader 0:  72%|████████████████████████████████████████▌               | 231/319 [01:36<00:36,  2.39it/s]
# Validation DataLoader 0:  73%|████████████████████████████████████████▋               | 232/319 [01:36<00:36,  2.40it/s]
# Validation DataLoader 0:  73%|████████████████████████████████████████▉               | 233/319 [01:36<00:35,  2.41it/s]
# Validation DataLoader 0:  73%|█████████████████████████████████████████               | 234/319 [01:38<00:35,  2.38it/s]
# Validation DataLoader 0:  74%|█████████████████████████████████████████▎              | 235/319 [01:38<00:35,  2.39it/s]
# Validation DataLoader 0:  74%|█████████████████████████████████████████▍              | 236/319 [01:38<00:34,  2.40it/s]
# Validation DataLoader 0:  74%|█████████████████████████████████████████▌              | 237/319 [01:38<00:34,  2.41it/s]
# Validation DataLoader 0:  75%|█████████████████████████████████████████▊              | 238/319 [01:39<00:34,  2.38it/s]
# Validation DataLoader 0:  75%|█████████████████████████████████████████▉              | 239/319 [01:39<00:33,  2.39it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▏             | 240/319 [01:39<00:32,  2.40it/s]
# Validation DataLoader 0:  76%|██████████████████████████████████████████▎             | 241/319 [01:39<00:32,  2.41it/s]
# Validation DataLoader 0:  76%|██████████████████████████████████████████▍             | 242/319 [01:41<00:32,  2.38it/s]
# Validation DataLoader 0:  76%|██████████████████████████████████████████▋             | 243/319 [01:41<00:31,  2.39it/s]
# Validation DataLoader 0:  76%|██████████████████████████████████████████▊             | 244/319 [01:41<00:31,  2.40it/s]
# Validation DataLoader 0:  77%|███████████████████████████████████████████             | 245/319 [01:41<00:30,  2.41it/s]
# Validation DataLoader 0:  77%|███████████████████████████████████████████▏            | 246/319 [01:43<00:30,  2.38it/s]
# Validation DataLoader 0:  77%|███████████████████████████████████████████▎            | 247/319 [01:43<00:30,  2.38it/s]
# Validation DataLoader 0:  78%|███████████████████████████████████████████▌            | 248/319 [01:43<00:29,  2.39it/s]
# Validation DataLoader 0:  78%|███████████████████████████████████████████▋            | 249/319 [01:43<00:29,  2.40it/s]
# Validation DataLoader 0:  78%|███████████████████████████████████████████▉            | 250/319 [01:45<00:29,  2.37it/s]
# Validation DataLoader 0:  79%|████████████████████████████████████████████            | 251/319 [01:45<00:28,  2.38it/s]
# Validation DataLoader 0:  79%|████████████████████████████████████████████▏           | 252/319 [01:45<00:28,  2.39it/s]
# Validation DataLoader 0:  79%|████████████████████████████████████████████▍           | 253/319 [01:45<00:27,  2.40it/s]
# Validation DataLoader 0:  80%|████████████████████████████████████████████▌           | 254/319 [01:47<00:27,  2.37it/s]
# Validation DataLoader 0:  80%|████████████████████████████████████████████▊           | 255/319 [01:47<00:26,  2.38it/s]
# Validation DataLoader 0:  80%|████████████████████████████████████████████▉           | 256/319 [01:47<00:26,  2.39it/s]
# Validation DataLoader 0:  81%|█████████████████████████████████████████████           | 257/319 [01:47<00:25,  2.40it/s]
# Validation DataLoader 0:  81%|█████████████████████████████████████████████▎          | 258/319 [01:48<00:25,  2.37it/s]
# Validation DataLoader 0:  81%|█████████████████████████████████████████████▍          | 259/319 [01:48<00:25,  2.38it/s]
# Validation DataLoader 0:  82%|█████████████████████████████████████████████▋          | 260/319 [01:48<00:24,  2.39it/s]
# Validation DataLoader 0:  82%|█████████████████████████████████████████████▊          | 261/319 [01:49<00:24,  2.39it/s]
# Validation DataLoader 0:  82%|█████████████████████████████████████████████▉          | 262/319 [01:50<00:24,  2.36it/s]
# Validation DataLoader 0:  82%|██████████████████████████████████████████████▏         | 263/319 [01:50<00:23,  2.37it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████████████▎         | 264/319 [01:50<00:23,  2.38it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████████████▌         | 265/319 [01:50<00:22,  2.39it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████████████▋         | 266/319 [01:52<00:22,  2.36it/s]
# Validation DataLoader 0:  84%|██████████████████████████████████████████████▊         | 267/319 [01:52<00:21,  2.37it/s]
# Validation DataLoader 0:  84%|███████████████████████████████████████████████         | 268/319 [01:52<00:21,  2.38it/s]
# Validation DataLoader 0:  84%|███████████████████████████████████████████████▏        | 269/319 [01:52<00:20,  2.39it/s]
# Validation DataLoader 0:  85%|███████████████████████████████████████████████▍        | 270/319 [01:54<00:20,  2.36it/s]
# Validation DataLoader 0:  85%|███████████████████████████████████████████████▌        | 271/319 [01:54<00:20,  2.37it/s]
# Validation DataLoader 0:  85%|███████████████████████████████████████████████▋        | 272/319 [01:54<00:19,  2.38it/s]
# Validation DataLoader 0:  86%|███████████████████████████████████████████████▉        | 273/319 [01:54<00:19,  2.39it/s]
# Validation DataLoader 0:  86%|████████████████████████████████████████████████        | 274/319 [01:56<00:19,  2.36it/s]
# Validation DataLoader 0:  86%|████████████████████████████████████████████████▎       | 275/319 [01:56<00:18,  2.37it/s]
# Validation DataLoader 0:  87%|████████████████████████████████████████████████▍       | 276/319 [01:56<00:18,  2.38it/s]
# Validation DataLoader 0:  87%|████████████████████████████████████████████████▋       | 277/319 [01:56<00:17,  2.38it/s]
# Validation DataLoader 0:  87%|████████████████████████████████████████████████▊       | 278/319 [01:57<00:17,  2.36it/s]
# Validation DataLoader 0:  87%|████████████████████████████████████████████████▉       | 279/319 [01:57<00:16,  2.36it/s]
# Validation DataLoader 0:  88%|█████████████████████████████████████████████████▏      | 280/319 [01:57<00:16,  2.37it/s]
# Validation DataLoader 0:  88%|█████████████████████████████████████████████████▎      | 281/319 [01:57<00:15,  2.38it/s]
# Validation DataLoader 0:  88%|█████████████████████████████████████████████████▌      | 282/319 [01:59<00:15,  2.35it/s]
# Validation DataLoader 0:  89%|█████████████████████████████████████████████████▋      | 283/319 [01:59<00:15,  2.36it/s]
# Validation DataLoader 0:  89%|█████████████████████████████████████████████████▊      | 284/319 [01:59<00:14,  2.37it/s]
# Validation DataLoader 0:  89%|██████████████████████████████████████████████████      | 285/319 [01:59<00:14,  2.38it/s]
# Validation DataLoader 0:  90%|██████████████████████████████████████████████████▏     | 286/319 [02:03<00:14,  2.32it/s]
# Validation DataLoader 0:  90%|██████████████████████████████████████████████████▍     | 287/319 [02:03<00:13,  2.33it/s]
# Validation DataLoader 0:  90%|██████████████████████████████████████████████████▌     | 288/319 [02:03<00:13,  2.33it/s]
# Validation DataLoader 0:  91%|██████████████████████████████████████████████████▋     | 289/319 [02:03<00:12,  2.34it/s]
# Validation DataLoader 0:  91%|██████████████████████████████████████████████████▉     | 290/319 [02:05<00:12,  2.32it/s]
# Validation DataLoader 0:  91%|███████████████████████████████████████████████████     | 291/319 [02:05<00:12,  2.32it/s]
# Validation DataLoader 0:  92%|███████████████████████████████████████████████████▎    | 292/319 [02:05<00:11,  2.33it/s]
# Validation DataLoader 0:  92%|███████████████████████████████████████████████████▍    | 293/319 [02:05<00:11,  2.34it/s]
# Validation DataLoader 0:  92%|███████████████████████████████████████████████████▌    | 294/319 [02:07<00:10,  2.31it/s]
# Validation DataLoader 0:  92%|███████████████████████████████████████████████████▊    | 295/319 [02:07<00:10,  2.32it/s]
# Validation DataLoader 0:  93%|███████████████████████████████████████████████████▉    | 296/319 [02:07<00:09,  2.33it/s]
# Validation DataLoader 0:  93%|████████████████████████████████████████████████████▏   | 297/319 [02:07<00:09,  2.34it/s]
# Validation DataLoader 0:  93%|████████████████████████████████████████████████████▎   | 298/319 [02:08<00:09,  2.32it/s]
# Validation DataLoader 0:  94%|████████████████████████████████████████████████████▍   | 299/319 [02:08<00:08,  2.32it/s]
# Validation DataLoader 0:  94%|████████████████████████████████████████████████████▋   | 300/319 [02:08<00:08,  2.33it/s]
# Validation DataLoader 0:  94%|████████████████████████████████████████████████████▊   | 301/319 [02:08<00:07,  2.34it/s]
# Validation DataLoader 0:  95%|█████████████████████████████████████████████████████   | 302/319 [02:10<00:07,  2.32it/s]
# Validation DataLoader 0:  95%|█████████████████████████████████████████████████████▏  | 303/319 [02:10<00:06,  2.32it/s]
# Validation DataLoader 0:  95%|█████████████████████████████████████████████████████▎  | 304/319 [02:10<00:06,  2.33it/s]
# Validation DataLoader 0:  96%|█████████████████████████████████████████████████████▌  | 305/319 [02:10<00:05,  2.34it/s]
# Validation DataLoader 0:  96%|█████████████████████████████████████████████████████▋  | 306/319 [02:11<00:05,  2.32it/s]
# Validation DataLoader 0:  96%|█████████████████████████████████████████████████████▉  | 307/319 [02:11<00:05,  2.33it/s]
# Validation DataLoader 0:  97%|██████████████████████████████████████████████████████  | 308/319 [02:11<00:04,  2.33it/s]
# Validation DataLoader 0:  97%|██████████████████████████████████████████████████████▏ | 309/319 [02:11<00:04,  2.34it/s]
# Validation DataLoader 0:  97%|██████████████████████████████████████████████████████▍ | 310/319 [02:13<00:03,  2.32it/s]
# Validation DataLoader 0:  97%|██████████████████████████████████████████████████████▌ | 311/319 [02:13<00:03,  2.33it/s]
# Validation DataLoader 0:  98%|██████████████████████████████████████████████████████▊ | 312/319 [02:13<00:02,  2.34it/s]
# Validation DataLoader 0:  98%|██████████████████████████████████████████████████████▉ | 313/319 [02:13<00:02,  2.34it/s]
# Validation DataLoader 0:  98%|███████████████████████████████████████████████████████ | 314/319 [02:15<00:02,  2.32it/s]
# Validation DataLoader 0:  99%|███████████████████████████████████████████████████████▎| 315/319 [02:15<00:01,  2.33it/s]
# Validation DataLoader 0:  99%|███████████████████████████████████████████████████████▍| 316/319 [02:15<00:01,  2.34it/s]
# Validation DataLoader 0:  99%|███████████████████████████████████████████████████████▋| 317/319 [02:15<00:00,  2.35it/s]
# Validation DataLoader 0: 100%|███████████████████████████████████████████████████████▊| 318/319 [02:16<00:00,  2.33it/s]
# Validation DataLoader 0: 100%|████████████████████████████████████████████████████████| 319/319 [02:16<00:00,  2.33it/s]
# Epoch 3:  29%|████          | 958/3314 [03:31<08:41,  4.52it/s, v_num=113, bce=0.00686, 182bce=0.00567, val_score=0.949]

# %%
## replicating metrics of actual model but with the same pipeline as previous
PATH_TO = CONFIG.checkpoint_dir

seed = CONFIG.seed
random.seed(seed)
torch.manual_seed(seed)

for f in range(CONFIG.folds):
    eval_df = train_df[train_df[f'fold'] == f].copy()

    val_ds = BirdDataset(eval_df, None, False, get_transforms('valid'),'valid')
    
    val_dl = torch.utils.data.DataLoader(
        val_ds,
        batch_size=CONFIG.batch_size * 2,
        shuffle=False,
        num_workers=CONFIG.n_workers,
        pin_memory=True,
        persistent_workers=True
    )
    
    bird_model = BirdModel(12)
    best_model_path = PATH_TO + f'/fold_{f}.ckpt'
    weights = torch.load(best_model_path)['state_dict']
    bird_model.load_state_dict(weights)

    preds, gts = predict(val_dl, bird_model)
    
    # = create dataframe =
    pred_df = pd.DataFrame(preds, columns=full_label_list)
    pred_df = pred_df[label_list]
    pred_df['id'] = np.arange(len(pred_df))
    gt_df = pd.DataFrame(gts, columns=full_label_list)
    gt_df = gt_df[label_list]
    gt_df['id'] = np.arange(len(gt_df))
    
    # = compute score =
    val_score = score(gt_df.apply(np.ceil), pred_df, row_id_column_name='id')
    
    preds_noised, gts_noised = predict_noised(eval_df, bird_model)
    
    # = create dataframe =
    # = create dataframe =
    pred_df_noised = pd.DataFrame(preds_noised, columns=full_label_list)
    pred_df_noised = pred_df_noised[label_list]
    pred_df_noised['id'] = np.arange(len(pred_df_noised))
    gt_df_noised = pd.DataFrame(gts_noised, columns=full_label_list)
    gt_df_noised = gt_df_noised[label_list]
    gt_df_noised['id'] = np.arange(len(gt_df_noised))
    
    # = compute score =
    val_score_noised = score(gt_df_noised.apply(np.ceil), pred_df_noised, row_id_column_name='id')

    print(f"Eval fold {f}: Val = {val_score}  Val noised = {val_score_noised}")

# %%
ckpt_list = glob(f'{CONFIG.checkpoint_dir}/*.ckpt')
print(f'find {len(ckpt_list)} ckpts in {CONFIG.checkpoint_dir}.')
#ckpt_list = [ckpt_list[-1]]
ckpt_list

# %%
# == setting of onnx ==

input_tensor = torch.randn(64, 128, 938)  # input shape
input_names = ['x']
output_names = ['output']

# %%
onnx_ckpt_list = list()
for ckpt_path in ckpt_list:
    ckpt_name = os.path.basename(ckpt_path).split('.')[0]
    # == init model ==
    bird_model = MyModel()
    
    # == load ckpt ==
    weights = torch.load(ckpt_path, map_location=torch.device('cpu'))['state_dict']
    bird_model.load_state_dict(weights)
    bird_model.eval()
    
    # == convert to onnx ==
    torch.onnx.export(bird_model, input_tensor, f"{CONFIG.checkpoint_dir}/{ckpt_name}.onnx", verbose=False, input_names=input_names, output_names=output_names)
#     onnx_ckpt_list.append(f"{ckpt_name}.onnx")
